# %% [markdown]
# # **Start Section:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Uninstall existing scikit-learn to avoid conflicts
# !pip uninstall -y scikit-learn
# Install specific versions of libraries to avoid conflicts
# !pip install scikit-learn==1.5.2
# !pip install bayesian-optimization
# !pip install optuna
# !pip install gpboost
# !pip install shap
# !pip install ngboost
# !pip install dask[dataframe]
# !pip install torch seaborn
# !pip install lightgbm
# !pip install xgboost
# !pip install lime
# !pip install interpret
# !pip install optunahub
# !pip install cmaes
# !pip install plotly kaleido
# !pip install openpyxl
# !pip install -U kaleido
# !pip install properscoring
# !pip install XlsxWriter
# !pip install cython
# !pip install pgbm
# !pip install torch
# !pip install cp
# !pip install mapie
# !pip install torch skorch puncc
# Reinstall scikit-learn to the version required by ngboost
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.6.1
# Reinstall numpy first
# !pip install numpy==1.26.4  # Use the version compatible with catboost
# Reinstall catboost
# !pip install catboost
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.8 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.5.2
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-2.0.3-py3-none-any.whl.metadata (9.0 kB)
# Collecting colorama<0.5.0,>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (2.0.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.6.0)
# Downloading bayesian_optimization-2.0.3-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-2.0.3 colorama-0.4.6
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.39)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 6.5 MB/s eta 0:00:00
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 12.4 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.1 colorlog-6.9.0 optuna-4.2.1
# Collecting gpboost
#   Downloading gpboost-1.5.6-py3-none-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from gpboost) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gpboost) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from gpboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.14.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.5.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from gpboost) (4.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (1.15.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (2.0.39)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->gpboost) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->gpboost) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->gpboost) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->gpboost) (3.1.1)
# Downloading gpboost-1.5.6-py3-none-manylinux1_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: gpboost
# Successfully installed gpboost-1.5.6
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.47.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.14.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Collecting ngboost
#   Downloading ngboost-0.5.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting lifelines>=0.25 (from ngboost)
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (2.0.2)
# Collecting scikit-learn<2.0,>=1.6 (from ngboost)
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.14.1)
# Requirement already satisfied: tqdm>=4.3 in /usr/local/lib/python3.11/dist-packages (from ngboost) (4.67.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (1.7.0)
# Collecting autograd-gamma>=0.3 (from lifelines>=0.25->ngboost)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines>=0.25->ngboost)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (3.6.0)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines>=0.25->ngboost)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines>=0.25->ngboost) (1.17.0)
# Downloading ngboost-0.5.5-py3-none-any.whl (33 kB)
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 9.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 62.4 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 7.5 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4031 sha256=a33341a213b113d7f71734731bac07b159090f553ebec2be6835b7990e769861
#   Stored in directory: /root/.cache/pip/wheels/8b/67/f4/2caaae2146198dcb824f31a303833b07b14a5ec863fb3acd7b
# Successfully built autograd-gamma
# Installing collected packages: interface-meta, scikit-learn, autograd-gamma, formulaic, lifelines, ngboost
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# Successfully installed autograd-gamma-0.5.0 formulaic-1.1.1 interface-meta-1.3.0 lifelines-0.30.0 ngboost-0.5.5 scikit-learn-1.6.1
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2024.12.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.6.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2.2.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.1.21)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 25.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.14.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.14.1)
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.3.13)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=bc0dc7a438f91c803ebcae0dbf2842b88d645397b34d2c2711bbb5f221803e6e
#   Stored in directory: /root/.cache/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1
# Collecting interpret
#   Downloading interpret-0.6.9-py3-none-any.whl.metadata (1.0 kB)
# Collecting interpret-core==0.6.9 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading interpret_core-0.6.9-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.0.2)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.18.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.4.2)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.9.5)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (6.17.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (7.34.0)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.24.1)
# Collecting SALib>=1.3.3 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading salib-1.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: shap>=0.28.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.47.0)
# Collecting dill>=0.2.5 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting aplr>=10.6.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading aplr-10.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting dash>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting dash-core-components>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-table>=4.1.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 22.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gevent>=1.3.6 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading gevent-24.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.32.3)
# Collecting Flask<3.1,>=1.0.4 (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.12.2)
# Collecting retrying (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (75.1.0)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.1.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (24.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.7.1)
# Collecting jedi>=0.16 (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (9.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2025.1.31)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.10.0)
# Collecting multiprocess (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18.1->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.3.7)
# Downloading interpret-0.6.9-py3-none-any.whl (1.4 kB)
# Downloading interpret_core-0.6.9-py3-none-any.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 60.0 MB/s eta 0:00:00
# Downloading aplr-10.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 70.0 MB/s eta 0:00:00
# Downloading dash-3.0.1-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 73.9 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 8.1 MB/s eta 0:00:00
# Downloading gevent-24.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 62.8 MB/s eta 0:00:00
# Downloading salib-1.5.1-py3-none-any.whl (778 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 37.1 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.6 MB/s eta 0:00:00
# ...
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (3.6.0)
# Downloading pgbm-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 7.5 MB/s eta 0:00:00
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 25.3 MB/s eta 0:00:00
# Installing collected packages: ninja, pgbm
# Successfully installed ninja-1.11.1.4 pgbm-2.3.0
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Collecting cp
#   Downloading cp-2020.12.3.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: cp
#   Building wheel for cp (setup.py) ... done
#   Created wheel for cp: filename=cp-2020.12.3-py3-none-any.whl size=1422 sha256=210cd039529852eb4e96699843a4cf6e96f34c052d498dbf0ff58ff823415932
#   Stored in directory: /root/.cache/pip/wheels/58/67/10/9ba963c5b021c764015a1463b9bb89a408fc37bbcde7436aa7
# Successfully built cp
# Installing collected packages: cp
# Successfully installed cp-2020.12.3
# Collecting mapie
#   Downloading MAPIE-0.9.2-py3-none-any.whl.metadata (12 kB)
# Collecting scikit-learn<1.6.0 (from mapie)
#   Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mapie) (1.14.1)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from mapie) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mapie) (24.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0->mapie) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0->mapie) (3.6.0)
# Downloading MAPIE-0.9.2-py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.1/178.1 kB 1.6 MB/s eta 0:00:00
# Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Installing collected packages: scikit-learn, mapie
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ngboost 0.5.5 requires scikit-learn<2.0,>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed mapie-0.9.2 scikit-learn-1.5.2
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting skorch
#   Downloading skorch-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting puncc
#   Downloading puncc-0.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from skorch) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.5.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.14.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from puncc) (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from puncc) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from puncc) (2.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.0->skorch) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->puncc) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->puncc) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->puncc) (1.17.0)
# Downloading skorch-1.1.0-py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.9/228.9 kB 4.3 MB/s eta 0:00:00
# Downloading puncc-0.8.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: skorch, puncc
# Successfully installed puncc-0.8.0 skorch-1.1.0
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Successfully uninstalled scikit-learn-1.5.2
# Collecting scikit-learn==1.6.1
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (3.6.0)
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mapie 0.9.2 requires scikit-learn<1.6.0, but you have scikit-learn 1.6.1 which is incompatible.
# Successfully installed scikit-learn-1.6.1
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 79.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mapie 0.9.2 requires scikit-learn<1.6.0, but you have scikit-learn 1.6.1 which is incompatible.
# Successfully installed numpy-1.26.4
# Collecting catboost
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.14.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
# Restart the runtime to apply changes
import os
os._exit(00)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from optuna.samplers import BaseSampler
from optuna.samplers import GridSampler
from optuna.samplers import TPESampler
from optuna.samplers import PartialFixedSampler
from optuna.samplers import CmaEsSampler
from optuna.samplers import QMCSampler
from optuna.samplers import NSGAIIISampler
from optuna.samplers import NSGAIISampler
from optuna.samplers import BruteForceSampler
from optuna.samplers import GPSampler
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
import properscoring as ps
import io
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
from mapie.subsample import Subsample
from mapie.regression import MapieRegressor
from deel.puncc.metrics import regression_sharpness, regression_mean_coverage
from deel.puncc.api.prediction import BasePredictor, DualPredictor
from deel.puncc.regression import SplitCP, CVPlus, CQR
from deel.puncc.plotting import plot_prediction_intervals
from sklearn.model_selection import train_test_split
from typing_extensions import TypedDict
from typing import Union
from mapie.metrics import regression_coverage_score
from sklearn.model_selection import KFold
from PIL import Image as PImage
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu124/split_decision...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/split_decision/build.ninja...
# Building extension module split_decision...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module split_decision...
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# No modifications detected for re-loaded extension module split_decision, skipping build step...
# Loading extension module split_decision...

# %%
train_data_path = "./drive/MyDrive/Concrete_ml/train.csv"
test_data_path = "./drive/MyDrive/Concrete_ml/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (189, 8)
# First 5 rows of training data:
#          C    mp     FA      CA       F       W_P    Adm    str
# 0  280.80  70.2  858.0  1183.0    0.00  0.450000  0.610  21.56
# 1  372.15   0.0  975.0   525.0   52.85  0.493081  7.000  34.00
# 2  360.00  75.0  975.0   525.0   40.00  0.509722  7.000  28.00
# 3  364.30   0.0  975.0   525.0  110.40  0.503706  7.000  42.00
# 4  315.00  31.5  780.0  1110.0    0.00  0.370000  5.355  25.82
#
# Shape of test data: (95, 8)
# First 5 rows of test data:
#          C     mp     FA     CA      F       W_P   Adm   str
# 0  364.30    0.0  975.0  525.0  60.40  0.503706   7.0  34.0
# 1  344.30   75.0  975.0  525.0  55.40  0.532965   7.0  36.0
# 2  390.00    0.0  975.0  525.0  60.00  0.470513   7.0  36.0
# 3  352.15   75.0  975.0  525.0  47.85  0.521085   7.0  35.0
# 4  400.00  160.0  801.0  801.0  40.00  0.300000  10.3  44.6

# %%
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
x_test= X_test
print("\nShape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (189, 7)
# Shape of y_train: (189,)
# Shape of X_test: (95, 7)
# Shape of y_test: (95,)

# %%
# Apply z-score normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Print the first five rows of the normalized data
print("\nFirst five rows of normalized X_train:")
print(X_train[:5])

print("\nFirst five rows of normalized X_test:")
print(X_test[:5])
# Out:
# First five rows of normalized X_train:
# [[-1.56879184  0.95792014 -0.09685034  1.33138508 -0.85369002  0.16810471
#   -0.08799752]
#  [ 0.40300047 -0.7708921   0.73537613 -0.93459372  0.061075    0.78285857
#   -0.0664621 ]
#  [ 0.14074238  1.07612953  0.73537613 -0.93459372 -0.16134185  1.020321
#   -0.0664621 ]
#  [ 0.233558   -0.7708921   0.73537613 -0.93459372  1.05719093  0.93447436
#   -0.0664621 ]
#  [-0.83058388  0.00485698 -0.65166799  1.07999229 -0.85369002 -0.97347298
#   -0.07200604]]
#
# First five rows of normalized X_test:
# [[ 0.233558   -0.7708921   0.73537613 -0.93459372  0.19175572  0.93447436
#   -0.0664621 ]
#  [-0.19814256  1.07612953  0.73537613 -0.93459372  0.1052122   1.35199213
#   -0.0664621 ]
#  [ 0.78829322 -0.7708921   0.73537613 -0.93459372  0.18483223  0.4608195
#   -0.0664621 ]
#  [-0.02870009  1.07612953  0.73537613 -0.93459372 -0.02546852  1.18246784
#   -0.0664621 ]
#  [ 1.0041435   3.1694207  -0.50229401  0.01587763 -0.16134185 -1.97235346
#   -0.05534052]]

# %% [markdown]
# # **Functions:**

# %%
feature_names = ['C', 'mp', 'FA', 'CA', 'F', 'W_P', 'Adm']

# %%
def get_best_model_params(results, model_name):
    # Map model names to dictionary keys, assuming keys are strings like 'XGBoost' and not objects
    model_keys = {
        'LightGBM': 'LightGBM',
        'XGBoost': 'XGBoost',
        'GPBoost': 'GPBoost',
        'NGBoost': 'NGBoost',
        'HGBR' : 'HistGradientBoosting',
        'PGBM' : 'PGBM'
    }

    # Ensure the requested model name is valid
    if model_name not in model_keys:
        raise ValueError(f"Model name '{model_name}' is not recognized. Available models are: {list(model_keys.keys())}")

    # Filter out entries for the specified model
    model_entries = {key: value for key, value in results.items() if key[0] == model_keys[model_name]}

    # Find the entry with the best (lowest) 'best_score'
    best_entry_key, best_entry_value = min(model_entries.items(), key=lambda item: item[1]['best_score'])

    # Return the best hyperparameters
    return best_entry_value['best_params']

# %%
def generate_and_save_plots(predictions_df, y_test, excel_path):
    # 1. Predicted vs. Actual Plot
    plt.figure(figsize=(12, 8))
    sns.scatterplot(x='Actual', y='Mean', data=predictions_df)
    plt.plot([predictions_df['Actual'].min(), predictions_df['Actual'].max()],
             [predictions_df['Actual'].min(), predictions_df['Actual'].max()],
             color='red', linestyle='--')
    plt.title('Predicted Strength vs. Actual Strength')
    plt.xlabel('Actual Strength')
    plt.ylabel('Predicted Mean Strength')
    plt.tight_layout()
    predicted_vs_actual_path = 'predicted_vs_actual.png'
    plt.savefig(predicted_vs_actual_path)
    plt.close()

    # 2. Uncertainty Bands
    plt.figure(figsize=(12, 8))
    plt.errorbar(x=range(len(predictions_df)), y=predictions_df['Mean'],
                 yerr=predictions_df['StdDev'], fmt='o', markersize=4, ecolor='red', elinewidth=1, capsize=5, alpha=0.7)
    plt.plot(range(len(predictions_df)), predictions_df['Mean'], color='black', linewidth=0.5, alpha=0.7)
    plt.title('Predicted Mean with Uncertainty Bands', fontsize=16)
    plt.xlabel('Sample Number', fontsize=14)
    plt.ylabel('Predicted Mean Strength')
    plt.tight_layout()
    uncertainty_bands_path = 'uncertainty_bands.png'
    plt.savefig(uncertainty_bands_path)
    plt.close()

    # 3. Histogram of Standard Deviations
    plt.figure(figsize=(12, 8))
    sns.histplot(predictions_df['StdDev'], bins=20, kde=True)
    plt.title('Distribution of Predicted Standard Deviations')
    plt.xlabel('Standard Deviation')
    plt.ylabel('Frequency')
    plt.tight_layout()
    histogram_stddev_path = 'histogram_stddev.png'
    plt.savefig(histogram_stddev_path)
    plt.close()

    # 4. Residual Plot
    residuals = predictions_df['Actual'] - predictions_df['Mean']
    plt.figure(figsize=(12, 8))
    sns.scatterplot(x=predictions_df['Mean'], y=residuals)
    plt.axhline(0, color='red', linestyle='--')
    plt.title('Residual Plot')
    plt.xlabel('Predicted Mean Strength')
    plt.ylabel('Residuals')
    plt.tight_layout()
    residual_plot_path = 'residual_plot.png'
    plt.savefig(residual_plot_path)
    plt.close()

    # Plot the standard deviation of the predictions
    plt.figure(figsize=(12, 6))
    plt.plot(
        predictions_df['StdDev'],
        label='Standard Deviation',
        color='green',
        marker='o',
        linestyle='dashed'
    )
    plt.xlabel('Sample Number')
    plt.ylabel('Standard Deviation')
    plt.title('Standard Deviation of Predictions')
    plt.legend(loc='upper left', fontsize='small', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
    plt.tight_layout()
    stddev_plot_path = 'stddev_plot.png'
    plt.savefig(stddev_plot_path)
    plt.close()

    # Plot the actual vs predicted mean with confidence intervals
    plt.figure(figsize=(12, 6))
    plt.plot(
        y_test,
        label='Actual Strength',
        color='black',
        marker='o',
        linestyle='dashed',
        linewidth=1,
        markersize=4
    )
    plt.plot(
        predictions_df['Mean'],
        label='Predicted Mean Strength',
        color='red',
        marker='x',
        linestyle='dashed',
        linewidth=1,
        markersize=4
    )
    confidence_interval = 1.96 * predictions_df['StdDev']
    plt.fill_between(
        np.arange(len(predictions_df)),
        predictions_df['Mean'] - confidence_interval,
        predictions_df['Mean'] + confidence_interval,
        color='blue',
        alpha=0.2,
        label='95% Confidence Interval'
    )
    plt.xlabel('Sample Number')
    plt.ylabel(' Concrete Strength')
    plt.title('Predictions with Confidence Intervals')
    plt.legend(loc='upper left', fontsize='small', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
    plt.tight_layout()
    prediction_plot_path = 'prediction_plot.png'
    plt.savefig(prediction_plot_path)
    plt.close()

    # Create a Pandas Excel writer using XlsxWriter as the engine.
    writer = pd.ExcelWriter(excel_path, engine='xlsxwriter')

    # Write the dataframe to a worksheet.
    predictions_df.to_excel(writer, sheet_name='Predictions', index=False)

    # Access the XlsxWriter workbook and worksheet objects from the writer object.
    workbook = writer.book

    # Insert the plots into new worksheets.
    worksheet_predicted_vs_actual = workbook.add_worksheet('Predicted vs Actual')
    worksheet_predicted_vs_actual.insert_image('A1', predicted_vs_actual_path)

    worksheet_uncertainty_bands = workbook.add_worksheet('Uncertainty Bands')
    worksheet_uncertainty_bands.insert_image('A1', uncertainty_bands_path)

    worksheet_histogram_stddev = workbook.add_worksheet('Histogram StdDev')
    worksheet_histogram_stddev.insert_image('A1', histogram_stddev_path)

    worksheet_residual_plot = workbook.add_worksheet('Residual Plot')
    worksheet_residual_plot.insert_image('A1', residual_plot_path)

    worksheet_stddev = workbook.add_worksheet('StdDev Plot')
    worksheet_stddev.insert_image('A1', stddev_plot_path)

    worksheet_prediction = workbook.add_worksheet('Predictions Plot')
    worksheet_prediction.insert_image('A1', prediction_plot_path)

    # Close the Pandas Excel writer and output the Excel file.
    writer.close()
    print(f"Excel file saved at {excel_path}")

    # Optionally, remove the image files now that they're embedded in the Excel file
    os.remove(predicted_vs_actual_path)
    os.remove(uncertainty_bands_path)
    os.remove(histogram_stddev_path)
    os.remove(residual_plot_path)
    os.remove(stddev_plot_path)
    os.remove(prediction_plot_path)

# %%
# Define the path to the folder
folder_path = "/content/drive/MyDrive/ml_concrete"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

def plot_metrics_and_save_to_excel(writer, predictions_df, y_true, model_name):
    # Calculate metrics
    mean_pred = predictions_df['Mean']
    std_pred = predictions_df['StdDev']

    # Sharpness is the standard deviation
    sharpness = std_pred.mean()

    # CRPS for each prediction
    crps_values =ps.crps_gaussian(y_true, mean_pred, std_pred)

    # Negative Log Likelihood (NLL) for each prediction
    nll_values = -norm.logpdf(y_true, loc=mean_pred, scale=std_pred)
    nll = nll_values.mean()

    # Calibration (Validity)
    percentiles = np.linspace(0, 100, 101)
    calibration = [np.mean((y_true <= np.percentile(mean_pred + std_pred * np.random.randn(*mean_pred.shape), p))) for p in percentiles]

    # Plotting
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    # Sharpness plot
    axs[0, 0].hist(std_pred, bins=30, color='skyblue', edgecolor='black')
    axs[0, 0].set_title(f'Sharpness (StdDev) for {model_name}')
    axs[0, 0].set_xlabel('Standard Deviation')
    axs[0, 0].set_ylabel('Frequency')

    # CRPS plot (distribution)
    axs[0, 1].hist(crps_values, bins=30, color='lightgreen', edgecolor='black')
    axs[0, 1].set_title(f'CRPS Distribution for {model_name}')
    axs[0, 1].set_xlabel('CRPS')
    axs[0, 1].set_ylabel('Frequency')

    # NLL plot (distribution)
    axs[1, 0].hist(nll_values, bins=30, color='salmon', edgecolor='black')
    axs[1, 0].set_title(f'NLL Distribution for {model_name}')
    axs[1, 0].set_xlabel('NLL')
    axs[1, 0].set_ylabel('Frequency')

    # Calibration plot
    axs[1, 1].plot(percentiles, calibration, label='Calibration Curve')
    axs[1, 1].plot(percentiles, percentiles / 100, linestyle='--', label='Perfect Calibration')
    axs[1, 1].set_title(f'Calibration (Validity) for {model_name}')
    axs[1, 1].set_xlabel('Predicted Percentile')
    axs[1, 1].set_ylabel('Observed Frequency')
    axs[1, 1].legend()

    plt.tight_layout()

    # Save plots to images
    plot_image_path = f'{model_name}_plots.png'
    fig.savefig(plot_image_path)
    plt.close(fig)

    # Write the dataframe to a worksheet.
  #  predictions_df.to_excel(writer, sheet_name=f'{model_name} Predictions', index=False)

    sheet_name = f'{model_name} Plots'
    if sheet_name not in writer.sheets:  # Check if sheet already exists
        # If sheet doesn't exist, create a new one
        worksheet = writer.book.add_worksheet(sheet_name)
    else:
        # If sheet exists, get the existing sheet object to avoid duplicates
        worksheet = writer.sheets[sheet_name]
    worksheet.insert_image('A1', plot_image_path)

# %% [markdown]
# # **Hyperparameter Tuning using Autosampler Optuna**

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Define objective and metric functions for PGBM
def mseloss_objective(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss


def hyperparameter_tuning_all(X_train, y_train, X_test, y_test):

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)


    models = {
        'XGBoost': (XGBRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'n_estimators': [100, 200, 300, 400, 500],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9]
        }),
        'GPBoost': (GPBoostRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'n_estimators': [100, 200, 300, 400, 500],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'alpha': [0.1, 0.5, 1.0],
            'lambda': [0.1, 0.5, 1.0],
            'verbose': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'n_estimators': [100, 200, 300, 400, 500],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'verbose': [-1]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [1, 5, 10],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False]
        }),
        'PGBM': (PGBM, {}) # PGBM is handled separately
    }

    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}

    for model_name, (model_class, param_space) in models.items():
        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            try:
                sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
                study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

                if model_name == 'PGBM':
                    def pgbm_objective(trial):
                        params = {
                            'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 1.0),
                            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
                            'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'n_estimators': trial.suggest_int('n_estimators', 50, 500),
                            'verbose': 0,
                            'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
                            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
                            'tree_correlation': trial.suggest_float('tree_correlation', 0.0, 0.5)
                        }

                        model = PGBM()


                        model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=params)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(pgbm_objective, n_trials=50)
                else:
                    def objective(trial, model_name, model_class, param_space):
                        params = {}
                        for key, values in param_space.items():
                            if isinstance(values, list):
                                params[key] = trial.suggest_categorical(key, values)
                            elif isinstance(values, tuple):
                                if len(values) == 2:
                                    params[key] = trial.suggest_float(key, values[0], values[1])
                                elif len(values) == 3 and isinstance(values[2], bool) and values[2]:
                                    params[key] = trial.suggest_int(key, values[0], values[1])
                                else:
                                    raise ValueError(f"Invalid parameter range for {key}")

                        model = model_class(**params)

                        model.fit(X_train, y_train)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(lambda trial: objective(trial, model_name, model_class, param_space), n_trials=50)

                best_params = study.best_params
                best_model = model_class(**best_params) if model_name != 'PGBM' else PGBM()
                if model_name == 'PGBM':
                    best_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params,)
                else:
                    best_model.fit(X_train, y_train)
                y_pred = best_model.predict(X_test)

                mse = mean_squared_error(y_test, y_pred)
                rmse = np.sqrt(mse)
                corr_coef = np.corrcoef(y_test, y_pred)[0, 1]

                best_scores[(model_name, pruner_name)] = {
                    'best_score': mse,
                    'best_params': best_params,
                    'test_mse': mse,
                    'test_rmse': rmse,
                    'test_corr_coef': corr_coef,
                    'pruner': pruner_name
                }
                print(f"Best MSE for {model_name} with {pruner_name}: {mse} with params: {best_params}")
                print(f"Best RMSE for {model_name} with {pruner_name}: {rmse}")
                print(f"Correlation Coefficient for {model_name} with {pruner_name}: {corr_coef}")
            except Exception as e:
                print(f"Failed to run Optuna for {model_name} with {pruner_name}. Error: {e}")

    if best_scores:
        best_model_name, best_pruner_name = min(best_scores, key=lambda k: best_scores[k]['test_mse'])
        best_model_info = best_scores[(best_model_name, best_pruner_name)]
        print(f"\nBest model on test data: {best_model_name} with {best_pruner_name}")
        print(f"Test MSE: {best_model_info['test_mse']}")
        print(f"Test RMSE: {best_model_info['test_rmse']}")
        print(f"Correlation Coefficient: {best_model_info['test_corr_coef']}")
        print(f"Best Parameters: {best_model_info['best_params']}")
        print(f"Pruner Used: {best_model_info['pruner']}")
    else:
        print("No valid model configurations found.")

    return best_scores

# Example usage
best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test)
# Out:
# Running Optuna for XGBoost with MedianPruner...
# Best MSE for XGBoost with MedianPruner: 7.831112188661016 with params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 500, 'min_child_weight': 5, 'gamma': 0, 'subsample': 0.9, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with MedianPruner: 2.798412440770841
# Correlation Coefficient for XGBoost with MedianPruner: 0.9601522669120696
# Running Optuna for XGBoost with NopPruner...
# Best MSE for XGBoost with NopPruner: 7.948356015301325 with params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'min_child_weight': 1, 'gamma': 1, 'subsample': 0.5, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with NopPruner: 2.8192828902579685
# Correlation Coefficient for XGBoost with NopPruner: 0.9596618508941466
# Running Optuna for XGBoost with PatientPruner...
# Best MSE for XGBoost with PatientPruner: 7.884869680408798 with params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 5, 'gamma': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with PatientPruner: 2.8080010114686207
# Correlation Coefficient for XGBoost with PatientPruner: 0.9599596852633636
# Running Optuna for XGBoost with PercentilePruner...
# Best MSE for XGBoost with PercentilePruner: 7.681722799878328 with params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 5, 'gamma': 0, 'subsample': 0.9, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with PercentilePruner: 2.7715921056097574
# Correlation Coefficient for XGBoost with PercentilePruner: 0.9611233978012462
# Running Optuna for XGBoost with SuccessiveHalvingPruner...
# Best MSE for XGBoost with SuccessiveHalvingPruner: 7.56289437188681 with params: {'learning_rate': 0.15, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 1, 'gamma': 0.5, 'subsample': 0.8, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with SuccessiveHalvingPruner: 2.7500717030446333
# Correlation Coefficient for XGBoost with SuccessiveHalvingPruner: 0.9620383595995261
# Running Optuna for XGBoost with HyperbandPruner...
# Best MSE for XGBoost with HyperbandPruner: 7.514544424534285 with params: {'learning_rate': 0.15, 'max_depth': 3, 'n_estimators': 300, 'min_child_weight': 1, 'gamma': 0, 'subsample': 0.7, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with HyperbandPruner: 2.741266937847222
# Correlation Coefficient for XGBoost with HyperbandPruner: 0.9624835179639377
# Running Optuna for XGBoost with ThresholdPruner...
# Best MSE for XGBoost with ThresholdPruner: 7.625412969147288 with params: {'learning_rate': 0.15, 'max_depth': 3, 'n_estimators': 200, 'min_child_weight': 3, 'gamma': 0.5, 'subsample': 0.5, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with ThresholdPruner: 2.7614150302240494
# Correlation Coefficient for XGBoost with ThresholdPruner: 0.9611214149586389
# Running Optuna for XGBoost with WilcoxonPruner...
# Best MSE for XGBoost with WilcoxonPruner: 7.681722799878328 with params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 5, 'gamma': 0, 'subsample': 0.9, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with WilcoxonPruner: 2.7715921056097574
# Correlation Coefficient for XGBoost with WilcoxonPruner: 0.9611233978012462
# Running Optuna for GPBoost with MedianPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with MedianPruner: 6.399496265648375 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'alpha': 0.5, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with MedianPruner: 2.5297225669326617
# Correlation Coefficient for GPBoost with MedianPruner: 0.9674088566075282
# Running Optuna for GPBoost with NopPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# Best MSE for GPBoost with NopPruner: 6.937717534676283 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'alpha': 1.0, 'lambda': 1.0, 'verbose': -1}
# Best RMSE for GPBoost with NopPruner: 2.6339547328449444
# Correlation Coefficient for GPBoost with NopPruner: 0.9646231681673647
# Running Optuna for GPBoost with PatientPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with PatientPruner: 6.472878269017162 with params: {'learning_rate': 0.15, 'max_depth': 3, 'n_estimators': 200, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.6, 'colsample_bytree': 0.5, 'alpha': 0.1, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with PatientPruner: 2.54418518764204
# Correlation Coefficient for GPBoost with PatientPruner: 0.9672213706525883
# Running Optuna for GPBoost with PercentilePruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with PercentilePruner: 6.779103186669849 with params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.7, 'colsample_bytree': 0.9, 'alpha': 0.5, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with PercentilePruner: 2.603671098020994
# Correlation Coefficient for GPBoost with PercentilePruner: 0.9654369696679301
# Running Optuna for GPBoost with SuccessiveHalvingPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with SuccessiveHalvingPruner: 6.779103186669849 with params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'alpha': 0.5, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with SuccessiveHalvingPruner: 2.603671098020994
# Correlation Coefficient for GPBoost with SuccessiveHalvingPruner: 0.9654369696679301
# Running Optuna for GPBoost with HyperbandPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with HyperbandPruner: 6.5798878786251525 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 300, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'alpha': 1.0, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with HyperbandPruner: 2.5651292128516943
# Correlation Coefficient for GPBoost with HyperbandPruner: 0.9664846026080294
# Running Optuna for GPBoost with ThresholdPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with ThresholdPruner: 6.626961600369569 with params: {'learning_rate': 0.15, 'max_depth': 5, 'n_estimators': 100, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'alpha': 0.1, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with ThresholdPruner: 2.574288561985538
# Correlation Coefficient for GPBoost with ThresholdPruner: 0.9661961763000706
# Running Optuna for GPBoost with WilcoxonPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# ...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/346, Train metric: 9.4282
# Estimator 1/346, Train metric: 8.8275
# Estimator 2/346, Train metric: 8.3786
# Estimator 3/346, Train metric: 7.9634
# Estimator 4/346, Train metric: 7.5126
# Estimator 5/346, Train metric: 7.1103
# Estimator 6/346, Train metric: 6.7103
# Estimator 7/346, Train metric: 6.3086
# Estimator 8/346, Train metric: 5.9867
# Estimator 9/346, Train metric: 5.6685
# Estimator 10/346, Train metric: 5.3939
# Estimator 11/346, Train metric: 5.0960
# Estimator 12/346, Train metric: 4.8518
# Estimator 13/346, Train metric: 4.6274
# Estimator 14/346, Train metric: 4.4368
# Estimator 15/346, Train metric: 4.2486
# Estimator 16/346, Train metric: 4.0442
# Estimator 17/346, Train metric: 3.8968
# Estimator 18/346, Train metric: 3.7374
# Estimator 19/346, Train metric: 3.5924
# Estimator 20/346, Train metric: 3.4259
# Estimator 21/346, Train metric: 3.3228
# Estimator 22/346, Train metric: 3.1946
# Estimator 23/346, Train metric: 3.0743
# Estimator 24/346, Train metric: 2.9615
# Estimator 25/346, Train metric: 2.8732
# Estimator 26/346, Train metric: 2.7871
# Estimator 27/346, Train metric: 2.7052
# Estimator 28/346, Train metric: 2.6170
# Estimator 29/346, Train metric: 2.5611
# Estimator 30/346, Train metric: 2.4969
# Estimator 31/346, Train metric: 2.4206
# Estimator 32/346, Train metric: 2.3495
# Estimator 33/346, Train metric: 2.3008
# Estimator 34/346, Train metric: 2.2276
# Estimator 35/346, Train metric: 2.1723
# Estimator 36/346, Train metric: 2.1072
# Estimator 37/346, Train metric: 2.0500
# Estimator 38/346, Train metric: 1.9881
# Estimator 39/346, Train metric: 1.9439
# Estimator 40/346, Train metric: 1.8746
# Estimator 41/346, Train metric: 1.8430
# Estimator 42/346, Train metric: 1.8100
# Estimator 43/346, Train metric: 1.7678
# Estimator 44/346, Train metric: 1.7476
# Estimator 45/346, Train metric: 1.7117
# Estimator 46/346, Train metric: 1.6930
# Estimator 47/346, Train metric: 1.6515
# Estimator 48/346, Train metric: 1.6230
# Estimator 49/346, Train metric: 1.6027
# Estimator 50/346, Train metric: 1.5633
# Estimator 51/346, Train metric: 1.5413
# Estimator 52/346, Train metric: 1.5068
# Estimator 53/346, Train metric: 1.4808
# Estimator 54/346, Train metric: 1.4367
# Estimator 55/346, Train metric: 1.4027
# Estimator 56/346, Train metric: 1.3793
# Estimator 57/346, Train metric: 1.3535
# Estimator 58/346, Train metric: 1.3187
# Estimator 59/346, Train metric: 1.3017
# Estimator 60/346, Train metric: 1.2888
# Estimator 61/346, Train metric: 1.2787
# Estimator 62/346, Train metric: 1.2497
# Estimator 63/346, Train metric: 1.2343
# Estimator 64/346, Train metric: 1.2144
# Estimator 65/346, Train metric: 1.2004
# Estimator 66/346, Train metric: 1.1812
# Estimator 67/346, Train metric: 1.1580
# Estimator 68/346, Train metric: 1.1486
# Estimator 69/346, Train metric: 1.1403
# Estimator 70/346, Train metric: 1.1248
# Estimator 71/346, Train metric: 1.1070
# Estimator 72/346, Train metric: 1.0938
# Estimator 73/346, Train metric: 1.0714
# Estimator 74/346, Train metric: 1.0652
# Estimator 75/346, Train metric: 1.0498
# Estimator 76/346, Train metric: 1.0376
# Estimator 77/346, Train metric: 1.0283
# Estimator 78/346, Train metric: 1.0175
# Estimator 79/346, Train metric: 1.0061
# Estimator 80/346, Train metric: 0.9913
# Estimator 81/346, Train metric: 0.9794
# Estimator 82/346, Train metric: 0.9605
# Estimator 83/346, Train metric: 0.9448
# Estimator 84/346, Train metric: 0.9407
# Estimator 85/346, Train metric: 0.9267
# Estimator 86/346, Train metric: 0.9135
# Estimator 87/346, Train metric: 0.9058
# Estimator 88/346, Train metric: 0.8969
# Estimator 89/346, Train metric: 0.8905
# Estimator 90/346, Train metric: 0.8828
# Estimator 91/346, Train metric: 0.8741
# Estimator 92/346, Train metric: 0.8690
# Estimator 93/346, Train metric: 0.8593
# Estimator 94/346, Train metric: 0.8517
# Estimator 95/346, Train metric: 0.8442
# Estimator 96/346, Train metric: 0.8340
# Estimator 97/346, Train metric: 0.8272
# Estimator 98/346, Train metric: 0.8177
# Estimator 99/346, Train metric: 0.8080
# Estimator 100/346, Train metric: 0.8017
# Estimator 101/346, Train metric: 0.7970
# Estimator 102/346, Train metric: 0.7939
# Estimator 103/346, Train metric: 0.7847
# Estimator 104/346, Train metric: 0.7815
# Estimator 105/346, Train metric: 0.7750
# Estimator 106/346, Train metric: 0.7674
# Estimator 107/346, Train metric: 0.7600
# Estimator 108/346, Train metric: 0.7549
# Estimator 109/346, Train metric: 0.7492
# Estimator 110/346, Train metric: 0.7440
# Estimator 111/346, Train metric: 0.7387
# Estimator 112/346, Train metric: 0.7337
# Estimator 113/346, Train metric: 0.7247
# Estimator 114/346, Train metric: 0.7230
# Estimator 115/346, Train metric: 0.7167
# Estimator 116/346, Train metric: 0.7101
# Estimator 117/346, Train metric: 0.7044
# Estimator 118/346, Train metric: 0.7016
# Estimator 119/346, Train metric: 0.6931
# Estimator 120/346, Train metric: 0.6875
# Estimator 121/346, Train metric: 0.6828
# Estimator 122/346, Train metric: 0.6786
# Estimator 123/346, Train metric: 0.6751
# Estimator 124/346, Train metric: 0.6704
# Estimator 125/346, Train metric: 0.6650
# Estimator 126/346, Train metric: 0.6596
# Estimator 127/346, Train metric: 0.6550
# Estimator 128/346, Train metric: 0.6531
# Estimator 129/346, Train metric: 0.6505
# Estimator 130/346, Train metric: 0.6454
# Estimator 131/346, Train metric: 0.6414
# Estimator 132/346, Train metric: 0.6383
# Estimator 133/346, Train metric: 0.6336
# Estimator 134/346, Train metric: 0.6296
# Estimator 135/346, Train metric: 0.6272
# Estimator 136/346, Train metric: 0.6238
# Estimator 137/346, Train metric: 0.6178
# Estimator 138/346, Train metric: 0.6164
# Estimator 139/346, Train metric: 0.6139
# Estimator 140/346, Train metric: 0.6109
# Estimator 141/346, Train metric: 0.6091
# Estimator 142/346, Train metric: 0.6076
# Estimator 143/346, Train metric: 0.6049
# Estimator 144/346, Train metric: 0.5997
# Estimator 145/346, Train metric: 0.5973
# Estimator 146/346, Train metric: 0.5920
# Estimator 147/346, Train metric: 0.5879
# Estimator 148/346, Train metric: 0.5851
# Estimator 149/346, Train metric: 0.5821
# Estimator 150/346, Train metric: 0.5785
# Estimator 151/346, Train metric: 0.5752
# Estimator 152/346, Train metric: 0.5739
# Estimator 153/346, Train metric: 0.5723
# Estimator 154/346, Train metric: 0.5697
# Estimator 155/346, Train metric: 0.5670
# Estimator 156/346, Train metric: 0.5632
# Estimator 157/346, Train metric: 0.5614
# Estimator 158/346, Train metric: 0.5594
# Estimator 159/346, Train metric: 0.5576
# Estimator 160/346, Train metric: 0.5551
# Estimator 161/346, Train metric: 0.5541
# Estimator 162/346, Train metric: 0.5524
# Estimator 163/346, Train metric: 0.5509
# Estimator 164/346, Train metric: 0.5481
# Estimator 165/346, Train metric: 0.5468
# Estimator 166/346, Train metric: 0.5449
# Estimator 167/346, Train metric: 0.5423
# Estimator 168/346, Train metric: 0.5412
# Estimator 169/346, Train metric: 0.5371
# Estimator 170/346, Train metric: 0.5361
# Estimator 171/346, Train metric: 0.5352
# Estimator 172/346, Train metric: 0.5339
# Estimator 173/346, Train metric: 0.5321
# Estimator 174/346, Train metric: 0.5308
# Estimator 175/346, Train metric: 0.5285
# Estimator 176/346, Train metric: 0.5248
# Estimator 177/346, Train metric: 0.5230
# Estimator 178/346, Train metric: 0.5203
# Estimator 179/346, Train metric: 0.5198
# Estimator 180/346, Train metric: 0.5186
# Estimator 181/346, Train metric: 0.5178
# Estimator 182/346, Train metric: 0.5162
# Estimator 183/346, Train metric: 0.5143
# Estimator 184/346, Train metric: 0.5129
# Estimator 185/346, Train metric: 0.5124
# Estimator 186/346, Train metric: 0.5106
# Estimator 187/346, Train metric: 0.5104
# Estimator 188/346, Train metric: 0.5094
# Estimator 189/346, Train metric: 0.5071
# Estimator 190/346, Train metric: 0.5047
# Estimator 191/346, Train metric: 0.5044
# Estimator 192/346, Train metric: 0.5031
# Estimator 193/346, Train metric: 0.5006
# Estimator 194/346, Train metric: 0.4978
# Estimator 195/346, Train metric: 0.4956
# Estimator 196/346, Train metric: 0.4947
# Estimator 197/346, Train metric: 0.4939
# Estimator 198/346, Train metric: 0.4922
# Estimator 199/346, Train metric: 0.4910
# Estimator 200/346, Train metric: 0.4905
# Estimator 201/346, Train metric: 0.4898
# Estimator 202/346, Train metric: 0.4891
# Estimator 203/346, Train metric: 0.4877
# Estimator 204/346, Train metric: 0.4869
# Estimator 205/346, Train metric: 0.4860
# Estimator 206/346, Train metric: 0.4855
# Estimator 207/346, Train metric: 0.4853
# Estimator 208/346, Train metric: 0.4842
# Estimator 209/346, Train metric: 0.4837
# Estimator 210/346, Train metric: 0.4828
# Estimator 211/346, Train metric: 0.4798
# Estimator 212/346, Train metric: 0.4791
# Estimator 213/346, Train metric: 0.4778
# Estimator 214/346, Train metric: 0.4767
# Estimator 215/346, Train metric: 0.4758
# Estimator 216/346, Train metric: 0.4753
# Estimator 217/346, Train metric: 0.4752
# Estimator 218/346, Train metric: 0.4744
# Estimator 219/346, Train metric: 0.4724
# Estimator 220/346, Train metric: 0.4726
# Estimator 221/346, Train metric: 0.4718
# Estimator 222/346, Train metric: 0.4720
# Estimator 223/346, Train metric: 0.4698
# Estimator 224/346, Train metric: 0.4693
# Estimator 225/346, Train metric: 0.4677
# Estimator 226/346, Train metric: 0.4673
# Estimator 227/346, Train metric: 0.4665
# Estimator 228/346, Train metric: 0.4651
# Estimator 229/346, Train metric: 0.4645
# Estimator 230/346, Train metric: 0.4641
# Estimator 231/346, Train metric: 0.4630
# Estimator 232/346, Train metric: 0.4617
# Estimator 233/346, Train metric: 0.4610
# Estimator 234/346, Train metric: 0.4602
# Estimator 235/346, Train metric: 0.4592
# Estimator 236/346, Train metric: 0.4587
# Estimator 237/346, Train metric: 0.4585
# Estimator 238/346, Train metric: 0.4574
# Estimator 239/346, Train metric: 0.4561
# Estimator 240/346, Train metric: 0.4557
# Estimator 241/346, Train metric: 0.4544
# Estimator 242/346, Train metric: 0.4537
# Estimator 243/346, Train metric: 0.4535
# Estimator 244/346, Train metric: 0.4526
# Estimator 245/346, Train metric: 0.4524
# Estimator 246/346, Train metric: 0.4518
# Estimator 247/346, Train metric: 0.4516
# Estimator 248/346, Train metric: 0.4511
# Estimator 249/346, Train metric: 0.4501
# Estimator 250/346, Train metric: 0.4498
# Estimator 251/346, Train metric: 0.4489
# Estimator 252/346, Train metric: 0.4486
# Estimator 253/346, Train metric: 0.4482
# Estimator 254/346, Train metric: 0.4477
# Estimator 255/346, Train metric: 0.4477
# Estimator 256/346, Train metric: 0.4469
# Estimator 257/346, Train metric: 0.4465
# Estimator 258/346, Train metric: 0.4462
# Estimator 259/346, Train metric: 0.4456
# Estimator 260/346, Train metric: 0.4450
# Estimator 261/346, Train metric: 0.4444
# Estimator 262/346, Train metric: 0.4439
# Estimator 263/346, Train metric: 0.4431
# Estimator 264/346, Train metric: 0.4431
# Estimator 265/346, Train metric: 0.4436
# Estimator 266/346, Train metric: 0.4429
# Estimator 267/346, Train metric: 0.4427
# Estimator 268/346, Train metric: 0.4431
# Estimator 269/346, Train metric: 0.4426
# Estimator 270/346, Train metric: 0.4426
# Estimator 271/346, Train metric: 0.4426
# Estimator 272/346, Train metric: 0.4423
# Estimator 273/346, Train metric: 0.4424
# Estimator 274/346, Train metric: 0.4422
# Estimator 275/346, Train metric: 0.4411
# Estimator 276/346, Train metric: 0.4410
# Estimator 277/346, Train metric: 0.4403
# Estimator 278/346, Train metric: 0.4397
# Estimator 279/346, Train metric: 0.4392
# Estimator 280/346, Train metric: 0.4386
# Estimator 281/346, Train metric: 0.4382
# Estimator 282/346, Train metric: 0.4377
# Estimator 283/346, Train metric: 0.4368
# Estimator 284/346, Train metric: 0.4372
# Estimator 285/346, Train metric: 0.4371
# Estimator 286/346, Train metric: 0.4365
# Estimator 287/346, Train metric: 0.4360
# Estimator 288/346, Train metric: 0.4355
# Estimator 289/346, Train metric: 0.4351
# Estimator 290/346, Train metric: 0.4350
# Estimator 291/346, Train metric: 0.4349
# Estimator 292/346, Train metric: 0.4344
# Estimator 293/346, Train metric: 0.4343
# Estimator 294/346, Train metric: 0.4340
# Estimator 295/346, Train metric: 0.4333
# Estimator 296/346, Train metric: 0.4329
# Estimator 297/346, Train metric: 0.4332
# Estimator 298/346, Train metric: 0.4333
# Estimator 299/346, Train metric: 0.4330
# Estimator 300/346, Train metric: 0.4328
# Estimator 301/346, Train metric: 0.4319
# Estimator 302/346, Train metric: 0.4318
# Estimator 303/346, Train metric: 0.4319
# Estimator 304/346, Train metric: 0.4317
# Estimator 305/346, Train metric: 0.4319
# Estimator 306/346, Train metric: 0.4319
# Estimator 307/346, Train metric: 0.4330
# Estimator 308/346, Train metric: 0.4322
# Estimator 309/346, Train metric: 0.4322
# Estimator 310/346, Train metric: 0.4320
# Estimator 311/346, Train metric: 0.4318
# Estimator 312/346, Train metric: 0.4326
# Estimator 313/346, Train metric: 0.4318
# Estimator 314/346, Train metric: 0.4315
# Estimator 315/346, Train metric: 0.4315
# Estimator 316/346, Train metric: 0.4306
# Estimator 317/346, Train metric: 0.4298
# Estimator 318/346, Train metric: 0.4291
# Estimator 319/346, Train metric: 0.4292
# Estimator 320/346, Train metric: 0.4286
# Estimator 321/346, Train metric: 0.4283
# Estimator 322/346, Train metric: 0.4279
# Estimator 323/346, Train metric: 0.4277
# Estimator 324/346, Train metric: 0.4273
# Estimator 325/346, Train metric: 0.4273
# Estimator 326/346, Train metric: 0.4271
# Estimator 327/346, Train metric: 0.4269
# Estimator 328/346, Train metric: 0.4267
# Estimator 329/346, Train metric: 0.4269
# Estimator 330/346, Train metric: 0.4266
# Estimator 331/346, Train metric: 0.4266
# Estimator 332/346, Train metric: 0.4264
# Estimator 333/346, Train metric: 0.4265
# Estimator 334/346, Train metric: 0.4268
# Estimator 335/346, Train metric: 0.4266
# Estimator 336/346, Train metric: 0.4270
# Estimator 337/346, Train metric: 0.4265
# Estimator 338/346, Train metric: 0.4257
# Estimator 339/346, Train metric: 0.4253
# Estimator 340/346, Train metric: 0.4252
# Estimator 341/346, Train metric: 0.4250
# Estimator 342/346, Train metric: 0.4248
# Estimator 343/346, Train metric: 0.4247
# Estimator 344/346, Train metric: 0.4245
# Estimator 345/346, Train metric: 0.4243
# Best MSE for PGBM with ThresholdPruner: 7.4663844635826955 with params: {'min_split_gain': 0.027539227572980024, 'learning_rate': 0.08406274270834382, 'reg_lambda': 1.2604916502716532, 'max_leaves': 25, 'n_estimators': 346, 'feature_fraction': 0.8676813712689422, 'bagging_fraction': 0.6710977982397303, 'tree_correlation': 0.2423867884664746}
# Best RMSE for PGBM with ThresholdPruner: 2.732468565891051
# Correlation Coefficient for PGBM with ThresholdPruner: 0.9621623251606423
# Running Optuna for PGBM with WilcoxonPruner...
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Training on CPU
# Estimator 0/500, Train metric: 8.9513
# Estimator 1/500, Train metric: 7.6858

# %%
best_scores_autosampler
# Out:
# {('XGBoost', 'MedianPruner'): {'best_score': 7.831112188661016,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 7,
#    'n_estimators': 500,
#    'min_child_weight': 5,
#    'gamma': 0,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7},
#   'test_mse': 7.831112188661016,
#   'test_rmse': 2.798412440770841,
#   'test_corr_coef': 0.9601522669120696,
#   'pruner': 'MedianPruner'},
#  ('XGBoost', 'NopPruner'): {'best_score': 7.948356015301325,
#   'best_params': {'learning_rate': 0.1,
#    'max_depth': 3,
#    'n_estimators': 500,
#    'min_child_weight': 1,
#    'gamma': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7},
#   'test_mse': 7.948356015301325,
#   'test_rmse': 2.8192828902579685,
#   'test_corr_coef': 0.9596618508941466,
#   'pruner': 'NopPruner'},
#  ('XGBoost', 'PatientPruner'): {'best_score': 7.884869680408798,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 7,
#    'n_estimators': 300,
#    'min_child_weight': 5,
#    'gamma': 0.1,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7},
#   'test_mse': 7.884869680408798,
#   'test_rmse': 2.8080010114686207,
#   'test_corr_coef': 0.9599596852633636,
#   'pruner': 'PatientPruner'},
#  ('XGBoost', 'PercentilePruner'): {'best_score': 7.681722799878328,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 7,
#    'n_estimators': 300,
#    'min_child_weight': 5,
#    'gamma': 0,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7},
#   'test_mse': 7.681722799878328,
#   'test_rmse': 2.7715921056097574,
#   'test_corr_coef': 0.9611233978012462,
#   'pruner': 'PercentilePruner'},
#  ('XGBoost', 'SuccessiveHalvingPruner'): {'best_score': 7.56289437188681,
#   'best_params': {'learning_rate': 0.15,
#    'max_depth': 7,
#    'n_estimators': 300,
#    'min_child_weight': 1,
#    'gamma': 0.5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.5},
#   'test_mse': 7.56289437188681,
#   'test_rmse': 2.7500717030446333,
#   'test_corr_coef': 0.9620383595995261,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('XGBoost', 'HyperbandPruner'): {'best_score': 7.514544424534285,
#   'best_params': {'learning_rate': 0.15,
#    'max_depth': 3,
#    'n_estimators': 300,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.7,
#    'colsample_bytree': 0.5},
#   'test_mse': 7.514544424534285,
#   'test_rmse': 2.741266937847222,
#   'test_corr_coef': 0.9624835179639377,
#   'pruner': 'HyperbandPruner'},
#  ('XGBoost', 'ThresholdPruner'): {'best_score': 7.625412969147288,
#   'best_params': {'learning_rate': 0.15,
#    'max_depth': 3,
#    'n_estimators': 200,
#    'min_child_weight': 3,
#    'gamma': 0.5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7},
#   'test_mse': 7.625412969147288,
#   'test_rmse': 2.7614150302240494,
#   'test_corr_coef': 0.9611214149586389,
#   'pruner': 'ThresholdPruner'},
#  ('XGBoost', 'WilcoxonPruner'): {'best_score': 7.681722799878328,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 7,
#    'n_estimators': 300,
#    'min_child_weight': 5,
#    'gamma': 0,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7},
#   'test_mse': 7.681722799878328,
#   'test_rmse': 2.7715921056097574,
#   'test_corr_coef': 0.9611233978012462,
#   'pruner': 'WilcoxonPruner'},
#  ('GPBoost', 'MedianPruner'): {'best_score': 6.399496265648375,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 400,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'alpha': 0.5,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.399496265648375,
#   'test_rmse': 2.5297225669326617,
#   'test_corr_coef': 0.9674088566075282,
#   'pruner': 'MedianPruner'},
#  ('GPBoost', 'NopPruner'): {'best_score': 6.937717534676283,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 500,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'alpha': 1.0,
#    'lambda': 1.0,
#    'verbose': -1},
#   'test_mse': 6.937717534676283,
#   'test_rmse': 2.6339547328449444,
#   'test_corr_coef': 0.9646231681673647,
#   'pruner': 'NopPruner'},
#  ('GPBoost', 'PatientPruner'): {'best_score': 6.472878269017162,
#   'best_params': {'learning_rate': 0.15,
#    'max_depth': 3,
#    'n_estimators': 200,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.5,
#    'alpha': 0.1,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.472878269017162,
#   'test_rmse': 2.54418518764204,
#   'test_corr_coef': 0.9672213706525883,
#   'pruner': 'PatientPruner'},
#  ('GPBoost', 'PercentilePruner'): {'best_score': 6.779103186669849,
#   'best_params': {'learning_rate': 0.1,
#    'max_depth': 5,
#    'n_estimators': 200,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.7,
#    'colsample_bytree': 0.9,
#    'alpha': 0.5,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.779103186669849,
#   'test_rmse': 2.603671098020994,
#   'test_corr_coef': 0.9654369696679301,
#   'pruner': 'PercentilePruner'},
#  ('GPBoost', 'SuccessiveHalvingPruner'): {'best_score': 6.779103186669849,
#   'best_params': {'learning_rate': 0.1,
#    'max_depth': 5,
#    'n_estimators': 200,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.9,
#    'alpha': 0.5,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.779103186669849,
#   'test_rmse': 2.603671098020994,
#   'test_corr_coef': 0.9654369696679301,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('GPBoost', 'HyperbandPruner'): {'best_score': 6.5798878786251525,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 300,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'alpha': 1.0,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.5798878786251525,
#   'test_rmse': 2.5651292128516943,
#   'test_corr_coef': 0.9664846026080294,
#   'pruner': 'HyperbandPruner'},
#  ('GPBoost', 'ThresholdPruner'): {'best_score': 6.626961600369569,
#   'best_params': {'learning_rate': 0.15,
#    'max_depth': 5,
#    'n_estimators': 100,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'alpha': 0.1,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.626961600369569,
#   'test_rmse': 2.574288561985538,
#   'test_corr_coef': 0.9661961763000706,
#   'pruner': 'ThresholdPruner'},
#  ('GPBoost', 'WilcoxonPruner'): {'best_score': 6.626961600369569,
#   'best_params': {'learning_rate': 0.15,
#    'max_depth': 5,
#    'n_estimators': 100,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'alpha': 1.0,
#    'lambda': 0.1,
#    'verbose': -1},
#   'test_mse': 6.626961600369569,
#   'test_rmse': 2.574288561985538,
#   'test_corr_coef': 0.9661961763000706,
#   'pruner': 'WilcoxonPruner'},
#  ('LightGBM', 'MedianPruner'): {'best_score': 6.2897838623647475,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 500,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.2897838623647475,
#   'test_rmse': 2.5079441505673024,
#   'test_corr_coef': 0.9679668253565256,
#   'pruner': 'MedianPruner'},
#  ('LightGBM', 'NopPruner'): {'best_score': 6.688709915593924,
#   'best_params': {'learning_rate': 0.1,
#    'max_depth': 5,
#    'n_estimators': 200,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.688709915593924,
#   'test_rmse': 2.586254031527824,
#   'test_corr_coef': 0.9659075309282348,
#   'pruner': 'NopPruner'},
#  ('LightGBM', 'PatientPruner'): {'best_score': 6.346665207312637,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 300,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.346665207312637,
#   'test_rmse': 2.5192588607192863,
#   'test_corr_coef': 0.9676487719838386,
#   'pruner': 'PatientPruner'},
#  ('LightGBM', 'PercentilePruner'): {'best_score': 6.2444486776418495,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 400,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.2444486776418495,
#   'test_rmse': 2.498889488881381,
#   'test_corr_coef': 0.9681860307455313,
#   'pruner': 'PercentilePruner'},
#  ('LightGBM', 'SuccessiveHalvingPruner'): {'best_score': 6.68573838882177,
#   'best_params': {'learning_rate': 0.1,
#    'max_depth': 7,
#    'n_estimators': 100,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.68573838882177,
#   'test_rmse': 2.585679483002828,
#   'test_corr_coef': 0.9660732130655002,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('LightGBM', 'HyperbandPruner'): {'best_score': 6.2444486776418495,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 400,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.2444486776418495,
#   'test_rmse': 2.498889488881381,
#   'test_corr_coef': 0.9681860307455313,
#   'pruner': 'HyperbandPruner'},
#  ('LightGBM', 'ThresholdPruner'): {'best_score': 6.2444486776418495,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 400,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.7,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.2444486776418495,
#   'test_rmse': 2.498889488881381,
#   'test_corr_coef': 0.9681860307455313,
#   'pruner': 'ThresholdPruner'},
#  ('LightGBM', 'WilcoxonPruner'): {'best_score': 6.346665207312637,
#   'best_params': {'learning_rate': 0.05,
#    'max_depth': 5,
#    'n_estimators': 300,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 0.8,
#    'colsample_bytree': 0.7,
#    'verbose': -1},
#   'test_mse': 6.346665207312637,
#   'test_rmse': 2.5192588607192863,
#   'test_corr_coef': 0.9676487719838386,
#   'pruner': 'WilcoxonPruner'},
#  ('NGBoost', 'MedianPruner'): {'best_score': 9.601473566669169,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'verbose': 0},
#   'test_mse': 9.601473566669169,
#   'test_rmse': 3.0986244636401437,
#   'test_corr_coef': 0.9507245127124856,
#   'pruner': 'MedianPruner'},
#  ('NGBoost', 'NopPruner'): {'best_score': 7.262012598896515,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'verbose': 0},
#   'test_mse': 7.262012598896515,
#   'test_rmse': 2.694812163935831,
#   'test_corr_coef': 0.9643763907344748,
#   'pruner': 'NopPruner'},
#  ('NGBoost', 'PatientPruner'): {'best_score': 10.757054139190643,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'verbose': 0},
#   'test_mse': 10.757054139190643,
#   'test_rmse': 3.2797948318744945,
#   'test_corr_coef': 0.9456995022678991,
#   'pruner': 'PatientPruner'},
#  ('NGBoost', 'PercentilePruner'): {'best_score': 11.324296989433229,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'verbose': 0},
#   'test_mse': 11.324296989433229,
#   'test_rmse': 3.3651592814357585,
#   'test_corr_coef': 0.9438153159846792,
#   'pruner': 'PercentilePruner'},
#  ('NGBoost', 'SuccessiveHalvingPruner'): {'best_score': 7.877071137974382,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'verbose': 0},
#   'test_mse': 7.877071137974382,
#   'test_rmse': 2.8066120390916844,
#   'test_corr_coef': 0.9601504294866189,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('NGBoost', 'HyperbandPruner'): {'best_score': 9.260732987964518,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.7,
#    'verbose': 0},
#   'test_mse': 9.260732987964518,
#   'test_rmse': 3.0431452459527,
#   'test_corr_coef': 0.952582589716971,
#   'pruner': 'HyperbandPruner'},
#  ('NGBoost', 'ThresholdPruner'): {'best_score': 10.679472014039193,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'verbose': 0},
#   'test_mse': 10.679472014039193,
#   'test_rmse': 3.267946146135091,
#   'test_corr_coef': 0.9466747596667691,
#   'pruner': 'ThresholdPruner'},
#  ('NGBoost', 'WilcoxonPruner'): {'best_score': 8.905260694581038,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.1,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'verbose': 0},
#   'test_mse': 8.905260694581038,
#   'test_rmse': 2.984168342198717,
#   'test_corr_coef': 0.9544973709553922,
#   'pruner': 'WilcoxonPruner'},
#  ('HistGradientBoosting', 'MedianPruner'): {'best_score': 6.970709180262843,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 100,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.1,
#    'max_bins': 128,
#    'early_stopping': False},
#   'test_mse': 6.970709180262843,
#   'test_rmse': 2.64021006366214,
#   'test_corr_coef': 0.9645103832168058,
#   'pruner': 'MedianPruner'},
#  ('HistGradientBoosting', 'NopPruner'): {'best_score': 10.11426000618758,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 200,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.1,
#    'max_bins': 255,
#    'early_stopping': True},
#   'test_mse': 10.11426000618758,
#   'test_rmse': 3.1802924403563235,
#   'test_corr_coef': 0.9485717205051889,
#   'pruner': 'NopPruner'},
#  ('HistGradientBoosting', 'PatientPruner'): {'best_score': 7.46136290217358,
#   'best_params': {'learning_rate': 0.05,
#    'max_iter': 300,
#    'max_depth': 5,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.0,
#    'max_bins': 255,
#    'early_stopping': False},
#   'test_mse': 7.46136290217358,
#   'test_rmse': 2.731549542324572,
#   'test_corr_coef': 0.9618984372040649,
#   'pruner': 'PatientPruner'},
#  ('HistGradientBoosting',
#   'PercentilePruner'): {'best_score': 7.323067966858103, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 200,
#    'max_depth': 5,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.1,
#    'max_bins': 64,
#    'early_stopping': False}, 'test_mse': 7.323067966858103, 'test_rmse': 2.7061167688882355, 'test_corr_coef': 0.9627605114567329, 'pruner': 'PercentilePruner'},
#  ('HistGradientBoosting',
#   'SuccessiveHalvingPruner'): {'best_score': 7.323067966858103, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 200,
#    'max_depth': 5,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.1,
#    'max_bins': 128,
#    'early_stopping': False}, 'test_mse': 7.323067966858103, 'test_rmse': 2.7061167688882355, 'test_corr_coef': 0.9627605114567329, 'pruner': 'SuccessiveHalvingPruner'},
#  ('HistGradientBoosting',
#   'HyperbandPruner'): {'best_score': 11.270100913831813, 'best_params': {'learning_rate': 0.1,
#    'max_iter': 200,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.5,
#    'max_bins': 64,
#    'early_stopping': True}, 'test_mse': 11.270100913831813, 'test_rmse': 3.3570970962770517, 'test_corr_coef': 0.942104001630108, 'pruner': 'HyperbandPruner'},
#  ('HistGradientBoosting', 'ThresholdPruner'): {'best_score': 7.923316648712569,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 100,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.1,
#    'max_bins': 64,
#    'early_stopping': False},
#   'test_mse': 7.923316648712569,
#   'test_rmse': 2.8148386541172425,
#   'test_corr_coef': 0.9595438553559239,
#   'pruner': 'ThresholdPruner'},
#  ('HistGradientBoosting', 'WilcoxonPruner'): {'best_score': 7.443302103733823,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 200,
#    'max_depth': 5,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.0,
#    'max_bins': 64,
#    'early_stopping': False},
#   'test_mse': 7.443302103733823,
#   'test_rmse': 2.7282415772313535,
#   'test_corr_coef': 0.9620393955851424,
#   'pruner': 'WilcoxonPruner'},
#  ('PGBM', 'MedianPruner'): {'best_score': 7.02508631283898,
#   'best_params': {'min_split_gain': 0.0,
#    'learning_rate': 0.08807032803940049,
#    'reg_lambda': 6.22952388205941,
#    'max_leaves': 15,
#    'n_estimators': 218,
#    'feature_fraction': 0.824990320756789,
#    'bagging_fraction': 0.6944653033824604,
#    'tree_correlation': 0.14324036555249958},
#   'test_mse': 7.02508631283898,
#   'test_rmse': 2.6504879386329945,
#   'test_corr_coef': 0.9641911814426343,
#   'pruner': 'MedianPruner'},
#  ('PGBM', 'NopPruner'): {'best_score': 7.377345919384039,
#   'best_params': {'min_split_gain': 0.034383798943110055,
#    'learning_rate': 0.1813736930468914,
#    'reg_lambda': 5.6238960566473555,
#    'max_leaves': 21,
#    'n_estimators': 297,
#    'feature_fraction': 0.9521475830723383,
#    'bagging_fraction': 0.6784468750089474,
#    'tree_correlation': 0.48921188673525984},
#   'test_mse': 7.377345919384039,
#   'test_rmse': 2.7161270072262895,
#   'test_corr_coef': 0.9632481010897539,
#   'pruner': 'NopPruner'},
#  ('PGBM', 'PatientPruner'): {'best_score': 7.053266873252206,
#   'best_params': {'min_split_gain': 0.4374839169160213,
#    'learning_rate': 0.052126121852205005,
#    'reg_lambda': 6.161391367711168,
#    'max_leaves': 33,
#    'n_estimators': 500,
#    'feature_fraction': 0.6218307463510174,
#    'bagging_fraction': 0.6097377332860419,
#    'tree_correlation': 0.5},
#   'test_mse': 7.053266873252206,
#   'test_rmse': 2.65579872604311,
#   'test_corr_coef': 0.963968236687184,
#   'pruner': 'PatientPruner'},
#  ('PGBM', 'PercentilePruner'): {'best_score': 7.285053144571397,
#   'best_params': {'min_split_gain': 1.0,
#    'learning_rate': 0.16778584717322106,
#    'reg_lambda': 10.0,
#    'max_leaves': 63,
#    'n_estimators': 500,
#    'feature_fraction': 0.6183401547203797,
#    'bagging_fraction': 0.6786612947970694,
#    'tree_correlation': 0.0},
#   'test_mse': 7.285053144571397,
#   'test_rmse': 2.699083760199264,
#   'test_corr_coef': 0.9628141904118481,
#   'pruner': 'PercentilePruner'},
#  ('PGBM', 'SuccessiveHalvingPruner'): {'best_score': 7.4374603720345345,
#   'best_params': {'min_split_gain': 0.32487428827789006,
#    'learning_rate': 0.09286069719924663,
#    'reg_lambda': 6.771423754364817,
#    'max_leaves': 19,
#    'n_estimators': 259,
#    'feature_fraction': 0.6891597794114357,
#    'bagging_fraction': 0.7788165044683306,
#    'tree_correlation': 0.26232640088307063},
#   'test_mse': 7.4374603720345345,
#   'test_rmse': 2.7271707632699744,
#   'test_corr_coef': 0.9620599610325083,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('PGBM', 'HyperbandPruner'): {'best_score': 7.013584177316712,
#   'best_params': {'min_split_gain': 0.3890248147105939,
#    'learning_rate': 0.1975237253568102,
#    'reg_lambda': 10.0,
#    'max_leaves': 63,
#    'n_estimators': 186,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7028326862997853,
#    'tree_correlation': 0.5},
#   'test_mse': 7.013584177316712,
#   'test_rmse': 2.6483172350224042,
#   'test_corr_coef': 0.964650350926234,
#   'pruner': 'HyperbandPruner'},
#  ('PGBM', 'ThresholdPruner'): {'best_score': 7.4663844635826955,
#   'best_params': {'min_split_gain': 0.027539227572980024,
#    'learning_rate': 0.08406274270834382,
#    'reg_lambda': 1.2604916502716532,
#    'max_leaves': 25,
#    'n_estimators': 346,
#    'feature_fraction': 0.8676813712689422,
#    'bagging_fraction': 0.6710977982397303,
#    'tree_correlation': 0.2423867884664746},
#   'test_mse': 7.4663844635826955,
#   'test_rmse': 2.732468565891051,
#   'test_corr_coef': 0.9621623251606423,
#   'pruner': 'ThresholdPruner'},
#  ('PGBM', 'WilcoxonPruner'): {'best_score': 6.347187046891611,
#   'best_params': {'min_split_gain': 0.252602528716432,
#    'learning_rate': 0.2,
#    'reg_lambda': 0.8309462814057811,
#    'max_leaves': 15,
#    'n_estimators': 500,
#    'feature_fraction': 1.0,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.0},
#   'test_mse': 6.347187046891611,
#   'test_rmse': 2.5193624286496794,
#   'test_corr_coef': 0.9683432541083656,
#   'pruner': 'WilcoxonPruner'}}

# %% [markdown]
# # **Probabilistic distributions using NGBoost**

# %%
# Assuming best_params is obtained correctly
best_params = get_best_model_params(best_scores_autosampler, 'NGBoost')

# Remove any conflicting parameters from best_params
incompatible_keys = ['Dist', 'Score']
for key in incompatible_keys:
    best_params.pop(key, None)

# Initialize NGBoost model with best_params
ngb_model = NGBRegressor(Dist=Normal, **best_params)

# Fit the model
ngb_model.fit(X_train, y_train)

# Predict the distribution
pred_dist = ngb_model.pred_dist(X_test)

# Extract mean and standard deviation
predictions_NGB_df = pd.DataFrame({
    'Mean': pred_dist.loc,
    'StdDev': pred_dist.scale,
    'Actual': y_test.ravel()
})

# Calculate and print the mean squared error
mse = mean_squared_error(y_test, pred_dist.loc)
print(f"Mean Squared Error: {mse:.2f}")

# Print the DataFrame with mean and standard deviation
print(predictions_NGB_df.head())
# Out:
# Mean Squared Error: 7.72
#         Mean    StdDev  Actual
# 0  32.703624  0.204403    34.0
# 1  36.913892  0.148120    36.0
# 2  34.518784  0.457365    36.0
# 3  36.885105  0.307971    35.0
# 4  53.945423  0.151028    44.6

# %%
generate_and_save_plots(predictions_NGB_df, y_test, "./drive/MyDrive/Concrete_ml/NGBoost_Prob.xlsx")
# Out:
# Excel file saved at ./drive/MyDrive/Concrete_ml/NGBoost_Prob.xlsx

# %% [markdown]
# # **Probabilistic distributions using PGBM**

# %%
# Assuming best_params is obtained correctly
best_params = get_best_model_params(best_scores_autosampler, 'PGBM')

# Remove any conflicting parameters from best_params
# Note: Adjust the incompatible keys based on PGBM's requirements
incompatible_keys = ['Dist', 'Score']
for key in incompatible_keys:
    best_params.pop(key, None)

# Initialize PGBM model
pgbm_model = PGBM()

def mseloss_objective(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
# Fit the model
pgbm_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params = best_params)

# Predict the distribution
pred_dist = pgbm_model.predict_dist(X_test)

# Extract mean and standard deviation
# Note: PGBM might return predictions in a different format, adjust accordingly
predictions_PGBM_df = pd.DataFrame({
    'Mean': pred_dist.mean(axis=0),
    'StdDev': pred_dist.std(axis=0),
    'Actual': y_test.ravel()
})

# Calculate and print the mean squared error
mse = mean_squared_error(y_test, predictions_PGBM_df['Mean'])
print(f"Mean Squared Error: {mse:.2f}")

# Print the DataFrame with mean and standard deviation
print(predictions_PGBM_df.head())
# Out:
# Training on CPU
# Estimator 0/500, Train metric: 8.9513
# Estimator 1/500, Train metric: 7.6858
# Estimator 2/500, Train metric: 6.7574
# Estimator 3/500, Train metric: 6.0336
# Estimator 4/500, Train metric: 5.5026
# Estimator 5/500, Train metric: 5.0000
# Estimator 6/500, Train metric: 4.5345
# Estimator 7/500, Train metric: 4.1367
# Estimator 8/500, Train metric: 3.8180
# Estimator 9/500, Train metric: 3.6479
# Estimator 10/500, Train metric: 3.3619
# Estimator 11/500, Train metric: 3.2063
# Estimator 12/500, Train metric: 3.0729
# Estimator 13/500, Train metric: 2.9013
# Estimator 14/500, Train metric: 2.7973
# Estimator 15/500, Train metric: 2.6872
# Estimator 16/500, Train metric: 2.6033
# Estimator 17/500, Train metric: 2.4705
# Estimator 18/500, Train metric: 2.3503
# Estimator 19/500, Train metric: 2.2712
# Estimator 20/500, Train metric: 2.1679
# Estimator 21/500, Train metric: 2.0350
# Estimator 22/500, Train metric: 1.9881
# Estimator 23/500, Train metric: 1.8908
# Estimator 24/500, Train metric: 1.8530
# Estimator 25/500, Train metric: 1.7955
# Estimator 26/500, Train metric: 1.7362
# Estimator 27/500, Train metric: 1.6960
# Estimator 28/500, Train metric: 1.6735
# Estimator 29/500, Train metric: 1.6422
# Estimator 30/500, Train metric: 1.6264
# Estimator 31/500, Train metric: 1.5802
# Estimator 32/500, Train metric: 1.5190
# Estimator 33/500, Train metric: 1.4673
# Estimator 34/500, Train metric: 1.4282
# Estimator 35/500, Train metric: 1.3954
# Estimator 36/500, Train metric: 1.3569
# Estimator 37/500, Train metric: 1.3355
# Estimator 38/500, Train metric: 1.3113
# Estimator 39/500, Train metric: 1.3243
# Estimator 40/500, Train metric: 1.3018
# Estimator 41/500, Train metric: 1.2702
# Estimator 42/500, Train metric: 1.2297
# Estimator 43/500, Train metric: 1.1967
# Estimator 44/500, Train metric: 1.1872
# Estimator 45/500, Train metric: 1.1599
# Estimator 46/500, Train metric: 1.1272
# Estimator 47/500, Train metric: 1.1034
# Estimator 48/500, Train metric: 1.0887
# Estimator 49/500, Train metric: 1.0584
# Estimator 50/500, Train metric: 1.0437
# Estimator 51/500, Train metric: 1.0258
# Estimator 52/500, Train metric: 1.0190
# Estimator 53/500, Train metric: 0.9838
# Estimator 54/500, Train metric: 0.9796
# Estimator 55/500, Train metric: 0.9698
# Estimator 56/500, Train metric: 0.9681
# Estimator 57/500, Train metric: 0.9451
# Estimator 58/500, Train metric: 0.9316
# Estimator 59/500, Train metric: 0.9144
# Estimator 60/500, Train metric: 0.9077
# Estimator 61/500, Train metric: 0.8995
# Estimator 62/500, Train metric: 0.8864
# Estimator 63/500, Train metric: 0.8798
# Estimator 64/500, Train metric: 0.8743
# Estimator 65/500, Train metric: 0.8664
# Estimator 66/500, Train metric: 0.8564
# Estimator 67/500, Train metric: 0.8447
# Estimator 68/500, Train metric: 0.8321
# Estimator 69/500, Train metric: 0.8254
# Estimator 70/500, Train metric: 0.8153
# Estimator 71/500, Train metric: 0.8072
# Estimator 72/500, Train metric: 0.7952
# Estimator 73/500, Train metric: 0.7854
# Estimator 74/500, Train metric: 0.7752
# Estimator 75/500, Train metric: 0.7712
# Estimator 76/500, Train metric: 0.7645
# Estimator 77/500, Train metric: 0.7598
# Estimator 78/500, Train metric: 0.7568
# Estimator 79/500, Train metric: 0.7513
# Estimator 80/500, Train metric: 0.7510
# Estimator 81/500, Train metric: 0.7424
# Estimator 82/500, Train metric: 0.7280
# Estimator 83/500, Train metric: 0.7210
# Estimator 84/500, Train metric: 0.7184
# Estimator 85/500, Train metric: 0.7078
# Estimator 86/500, Train metric: 0.7028
# Estimator 87/500, Train metric: 0.6940
# Estimator 88/500, Train metric: 0.6872
# Estimator 89/500, Train metric: 0.6799
# Estimator 90/500, Train metric: 0.6758
# Estimator 91/500, Train metric: 0.6729
# Estimator 92/500, Train metric: 0.6693
# Estimator 93/500, Train metric: 0.6629
# Estimator 94/500, Train metric: 0.6537
# Estimator 95/500, Train metric: 0.6533
# Estimator 96/500, Train metric: 0.6450
# Estimator 97/500, Train metric: 0.6401
# Estimator 98/500, Train metric: 0.6385
# Estimator 99/500, Train metric: 0.6341
# Estimator 100/500, Train metric: 0.6291
# Estimator 101/500, Train metric: 0.6265
# Estimator 102/500, Train metric: 0.6211
# Estimator 103/500, Train metric: 0.6211
# Estimator 104/500, Train metric: 0.6169
# Estimator 105/500, Train metric: 0.6094
# Estimator 106/500, Train metric: 0.6036
# Estimator 107/500, Train metric: 0.5992
# Estimator 108/500, Train metric: 0.5962
# Estimator 109/500, Train metric: 0.5909
# Estimator 110/500, Train metric: 0.5787
# Estimator 111/500, Train metric: 0.5754
# Estimator 112/500, Train metric: 0.5740
# Estimator 113/500, Train metric: 0.5727
# Estimator 114/500, Train metric: 0.5686
# Estimator 115/500, Train metric: 0.5646
# Estimator 116/500, Train metric: 0.5606
# Estimator 117/500, Train metric: 0.5598
# Estimator 118/500, Train metric: 0.5554
# Estimator 119/500, Train metric: 0.5544
# Estimator 120/500, Train metric: 0.5541
# Estimator 121/500, Train metric: 0.5562
# Estimator 122/500, Train metric: 0.5549
# Estimator 123/500, Train metric: 0.5546
# Estimator 124/500, Train metric: 0.5480
# Estimator 125/500, Train metric: 0.5452
# Estimator 126/500, Train metric: 0.5451
# Estimator 127/500, Train metric: 0.5446
# Estimator 128/500, Train metric: 0.5434
# Estimator 129/500, Train metric: 0.5445
# Estimator 130/500, Train metric: 0.5435
# Estimator 131/500, Train metric: 0.5435
# Estimator 132/500, Train metric: 0.5439
# Estimator 133/500, Train metric: 0.5379
# Estimator 134/500, Train metric: 0.5311
# Estimator 135/500, Train metric: 0.5290
# Estimator 136/500, Train metric: 0.5282
# Estimator 137/500, Train metric: 0.5251
# Estimator 138/500, Train metric: 0.5236
# Estimator 139/500, Train metric: 0.5239
# Estimator 140/500, Train metric: 0.5256
# Estimator 141/500, Train metric: 0.5241
# Estimator 142/500, Train metric: 0.5202
# Estimator 143/500, Train metric: 0.5198
# Estimator 144/500, Train metric: 0.5181
# Estimator 145/500, Train metric: 0.5164
# Estimator 146/500, Train metric: 0.5158
# Estimator 147/500, Train metric: 0.5148
# Estimator 148/500, Train metric: 0.5142
# Estimator 149/500, Train metric: 0.5109
# Estimator 150/500, Train metric: 0.5119
# Estimator 151/500, Train metric: 0.5123
# Estimator 152/500, Train metric: 0.5119
# Estimator 153/500, Train metric: 0.5118
# Estimator 154/500, Train metric: 0.5118
# Estimator 155/500, Train metric: 0.5128
# Estimator 156/500, Train metric: 0.5107
# Estimator 157/500, Train metric: 0.5051
# Estimator 158/500, Train metric: 0.5052
# Estimator 159/500, Train metric: 0.5047
# Estimator 160/500, Train metric: 0.5046
# Estimator 161/500, Train metric: 0.5048
# Estimator 162/500, Train metric: 0.5043
# Estimator 163/500, Train metric: 0.5060
# Estimator 164/500, Train metric: 0.5071
# Estimator 165/500, Train metric: 0.5053
# Estimator 166/500, Train metric: 0.5046
# Estimator 167/500, Train metric: 0.5045
# Estimator 168/500, Train metric: 0.5050
# Estimator 169/500, Train metric: 0.5074
# Estimator 170/500, Train metric: 0.5077
# Estimator 171/500, Train metric: 0.5058
# Estimator 172/500, Train metric: 0.5028
# Estimator 173/500, Train metric: 0.5021
# Estimator 174/500, Train metric: 0.4995
# Estimator 175/500, Train metric: 0.4986
# Estimator 176/500, Train metric: 0.4987
# Estimator 177/500, Train metric: 0.5011
# Estimator 178/500, Train metric: 0.5002
# Estimator 179/500, Train metric: 0.4977
# Estimator 180/500, Train metric: 0.4976
# Estimator 181/500, Train metric: 0.4990
# Estimator 182/500, Train metric: 0.5002
# Estimator 183/500, Train metric: 0.5003
# Estimator 184/500, Train metric: 0.4977
# Estimator 185/500, Train metric: 0.4988
# Estimator 186/500, Train metric: 0.4983
# Estimator 187/500, Train metric: 0.5004
# Estimator 188/500, Train metric: 0.4996
# Estimator 189/500, Train metric: 0.4985
# Estimator 190/500, Train metric: 0.4986
# Estimator 191/500, Train metric: 0.4961
# Estimator 192/500, Train metric: 0.4958
# Estimator 193/500, Train metric: 0.4966
# Estimator 194/500, Train metric: 0.4924
# Estimator 195/500, Train metric: 0.4921
# Estimator 196/500, Train metric: 0.4922
# Estimator 197/500, Train metric: 0.4913
# Estimator 198/500, Train metric: 0.4920
# Estimator 199/500, Train metric: 0.4920
# Estimator 200/500, Train metric: 0.4913
# Estimator 201/500, Train metric: 0.4943
# Estimator 202/500, Train metric: 0.4956
# Estimator 203/500, Train metric: 0.4954
# Estimator 204/500, Train metric: 0.4936
# Estimator 205/500, Train metric: 0.4937
# Estimator 206/500, Train metric: 0.4948
# Estimator 207/500, Train metric: 0.4912
# Estimator 208/500, Train metric: 0.4912
# Estimator 209/500, Train metric: 0.4908
# Estimator 210/500, Train metric: 0.4878
# Estimator 211/500, Train metric: 0.4879
# Estimator 212/500, Train metric: 0.4891
# Estimator 213/500, Train metric: 0.4906
# Estimator 214/500, Train metric: 0.4888
# Estimator 215/500, Train metric: 0.4866
# Estimator 216/500, Train metric: 0.4853
# Estimator 217/500, Train metric: 0.4869
# Estimator 218/500, Train metric: 0.4870
# Estimator 219/500, Train metric: 0.4861
# Estimator 220/500, Train metric: 0.4851
# Estimator 221/500, Train metric: 0.4850
# Estimator 222/500, Train metric: 0.4850
# Estimator 223/500, Train metric: 0.4827
# Estimator 224/500, Train metric: 0.4862
# Estimator 225/500, Train metric: 0.4844
# Estimator 226/500, Train metric: 0.4843
# Estimator 227/500, Train metric: 0.4835
# Estimator 228/500, Train metric: 0.4854
# Estimator 229/500, Train metric: 0.4824
# Estimator 230/500, Train metric: 0.4837
# Estimator 231/500, Train metric: 0.4842
# Estimator 232/500, Train metric: 0.4831
# Estimator 233/500, Train metric: 0.4824
# Estimator 234/500, Train metric: 0.4809
# Estimator 235/500, Train metric: 0.4809
# Estimator 236/500, Train metric: 0.4802
# Estimator 237/500, Train metric: 0.4805
# Estimator 238/500, Train metric: 0.4805
# Estimator 239/500, Train metric: 0.4795
# Estimator 240/500, Train metric: 0.4785
# Estimator 241/500, Train metric: 0.4782
# Estimator 242/500, Train metric: 0.4783
# Estimator 243/500, Train metric: 0.4790
# Estimator 244/500, Train metric: 0.4818
# Estimator 245/500, Train metric: 0.4815
# Estimator 246/500, Train metric: 0.4796
# Estimator 247/500, Train metric: 0.4811
# Estimator 248/500, Train metric: 0.4803
# Estimator 249/500, Train metric: 0.4809
# Estimator 250/500, Train metric: 0.4800
# Estimator 251/500, Train metric: 0.4792
# Estimator 252/500, Train metric: 0.4798
# Estimator 253/500, Train metric: 0.4787
# Estimator 254/500, Train metric: 0.4780
# Estimator 255/500, Train metric: 0.4775
# Estimator 256/500, Train metric: 0.4767
# Estimator 257/500, Train metric: 0.4785
# Estimator 258/500, Train metric: 0.4785
# Estimator 259/500, Train metric: 0.4777
# Estimator 260/500, Train metric: 0.4778
# Estimator 261/500, Train metric: 0.4788
# Estimator 262/500, Train metric: 0.4768
# Estimator 263/500, Train metric: 0.4813
# Estimator 264/500, Train metric: 0.4836
# Estimator 265/500, Train metric: 0.4815
# Estimator 266/500, Train metric: 0.4807
# Estimator 267/500, Train metric: 0.4828
# Estimator 268/500, Train metric: 0.4823
# Estimator 269/500, Train metric: 0.4822
# Estimator 270/500, Train metric: 0.4811
# Estimator 271/500, Train metric: 0.4798
# Estimator 272/500, Train metric: 0.4806
# Estimator 273/500, Train metric: 0.4841
# Estimator 274/500, Train metric: 0.4835
# Estimator 275/500, Train metric: 0.4808
# Estimator 276/500, Train metric: 0.4799
# Estimator 277/500, Train metric: 0.4792
# Estimator 278/500, Train metric: 0.4807
# Estimator 279/500, Train metric: 0.4807
# Estimator 280/500, Train metric: 0.4789
# Estimator 281/500, Train metric: 0.4785
# Estimator 282/500, Train metric: 0.4772
# Estimator 283/500, Train metric: 0.4782
# Estimator 284/500, Train metric: 0.4754
# Estimator 285/500, Train metric: 0.4742
# Estimator 286/500, Train metric: 0.4747
# Estimator 287/500, Train metric: 0.4753
# Estimator 288/500, Train metric: 0.4770
# Estimator 289/500, Train metric: 0.4775
# Estimator 290/500, Train metric: 0.4769
# Estimator 291/500, Train metric: 0.4791
# Estimator 292/500, Train metric: 0.4784
# Estimator 293/500, Train metric: 0.4784
# Estimator 294/500, Train metric: 0.4773
# Estimator 295/500, Train metric: 0.4761
# Estimator 296/500, Train metric: 0.4749
# Estimator 297/500, Train metric: 0.4754
# Estimator 298/500, Train metric: 0.4757
# Estimator 299/500, Train metric: 0.4797
# Estimator 300/500, Train metric: 0.4785
# Estimator 301/500, Train metric: 0.4779
# Estimator 302/500, Train metric: 0.4781
# Estimator 303/500, Train metric: 0.4757
# Estimator 304/500, Train metric: 0.4758
# Estimator 305/500, Train metric: 0.4763
# Estimator 306/500, Train metric: 0.4757
# Estimator 307/500, Train metric: 0.4758
# Estimator 308/500, Train metric: 0.4769
# Estimator 309/500, Train metric: 0.4766
# Estimator 310/500, Train metric: 0.4766
# Estimator 311/500, Train metric: 0.4751
# Estimator 312/500, Train metric: 0.4757
# Estimator 313/500, Train metric: 0.4762
# Estimator 314/500, Train metric: 0.4759
# Estimator 315/500, Train metric: 0.4767
# Estimator 316/500, Train metric: 0.4760
# Estimator 317/500, Train metric: 0.4755
# Estimator 318/500, Train metric: 0.4741
# Estimator 319/500, Train metric: 0.4742
# Estimator 320/500, Train metric: 0.4761
# Estimator 321/500, Train metric: 0.4749
# Estimator 322/500, Train metric: 0.4761
# Estimator 323/500, Train metric: 0.4751
# Estimator 324/500, Train metric: 0.4751
# Estimator 325/500, Train metric: 0.4752
# Estimator 326/500, Train metric: 0.4760
# Estimator 327/500, Train metric: 0.4734
# Estimator 328/500, Train metric: 0.4724
# Estimator 329/500, Train metric: 0.4718
# Estimator 330/500, Train metric: 0.4732
# Estimator 331/500, Train metric: 0.4715
# Estimator 332/500, Train metric: 0.4715
# Estimator 333/500, Train metric: 0.4717
# Estimator 334/500, Train metric: 0.4702
# Estimator 335/500, Train metric: 0.4703
# Estimator 336/500, Train metric: 0.4686
# Estimator 337/500, Train metric: 0.4674
# Estimator 338/500, Train metric: 0.4675
# Estimator 339/500, Train metric: 0.4675
# Estimator 340/500, Train metric: 0.4673
# Estimator 341/500, Train metric: 0.4669
# Estimator 342/500, Train metric: 0.4665
# Estimator 343/500, Train metric: 0.4660
# Estimator 344/500, Train metric: 0.4652
# Estimator 345/500, Train metric: 0.4643
# Estimator 346/500, Train metric: 0.4651
# Estimator 347/500, Train metric: 0.4655
# Estimator 348/500, Train metric: 0.4655
# Estimator 349/500, Train metric: 0.4660
# Estimator 350/500, Train metric: 0.4645
# Estimator 351/500, Train metric: 0.4647
# Estimator 352/500, Train metric: 0.4640
# Estimator 353/500, Train metric: 0.4648
# Estimator 354/500, Train metric: 0.4644
# Estimator 355/500, Train metric: 0.4648
# Estimator 356/500, Train metric: 0.4654
# Estimator 357/500, Train metric: 0.4653
# Estimator 358/500, Train metric: 0.4669
# Estimator 359/500, Train metric: 0.4647
# Estimator 360/500, Train metric: 0.4662
# Estimator 361/500, Train metric: 0.4657
# Estimator 362/500, Train metric: 0.4698
# Estimator 363/500, Train metric: 0.4658
# Estimator 364/500, Train metric: 0.4657
# Estimator 365/500, Train metric: 0.4654
# Estimator 366/500, Train metric: 0.4660
# Estimator 367/500, Train metric: 0.4670
# Estimator 368/500, Train metric: 0.4658
# Estimator 369/500, Train metric: 0.4666
# Estimator 370/500, Train metric: 0.4647
# Estimator 371/500, Train metric: 0.4672
# Estimator 372/500, Train metric: 0.4669
# Estimator 373/500, Train metric: 0.4659
# Estimator 374/500, Train metric: 0.4660
# Estimator 375/500, Train metric: 0.4663
# Estimator 376/500, Train metric: 0.4648
# Estimator 377/500, Train metric: 0.4647
# Estimator 378/500, Train metric: 0.4660
# Estimator 379/500, Train metric: 0.4673
# Estimator 380/500, Train metric: 0.4673
# Estimator 381/500, Train metric: 0.4658
# Estimator 382/500, Train metric: 0.4671
# Estimator 383/500, Train metric: 0.4672
# Estimator 384/500, Train metric: 0.4689
# Estimator 385/500, Train metric: 0.4701
# Estimator 386/500, Train metric: 0.4735
# Estimator 387/500, Train metric: 0.4755
# Estimator 388/500, Train metric: 0.4772
# Estimator 389/500, Train metric: 0.4764
# Estimator 390/500, Train metric: 0.4744
# Estimator 391/500, Train metric: 0.4716
# Estimator 392/500, Train metric: 0.4691
# Estimator 393/500, Train metric: 0.4655
# Estimator 394/500, Train metric: 0.4658
# Estimator 395/500, Train metric: 0.4665
# Estimator 396/500, Train metric: 0.4657
# Estimator 397/500, Train metric: 0.4682
# Estimator 398/500, Train metric: 0.4709
# Estimator 399/500, Train metric: 0.4668
# Estimator 400/500, Train metric: 0.4663
# Estimator 401/500, Train metric: 0.4678
# Estimator 402/500, Train metric: 0.4660
# Estimator 403/500, Train metric: 0.4660
# Estimator 404/500, Train metric: 0.4671
# Estimator 405/500, Train metric: 0.4674
# Estimator 406/500, Train metric: 0.4685
# Estimator 407/500, Train metric: 0.4661
# Estimator 408/500, Train metric: 0.4650
# Estimator 409/500, Train metric: 0.4648
# Estimator 410/500, Train metric: 0.4645
# Estimator 411/500, Train metric: 0.4652
# Estimator 412/500, Train metric: 0.4656
# Estimator 413/500, Train metric: 0.4662
# Estimator 414/500, Train metric: 0.4662
# Estimator 415/500, Train metric: 0.4661
# Estimator 416/500, Train metric: 0.4671
# Estimator 417/500, Train metric: 0.4679
# Estimator 418/500, Train metric: 0.4714
# Estimator 419/500, Train metric: 0.4731
# Estimator 420/500, Train metric: 0.4687
# Estimator 421/500, Train metric: 0.4661
# Estimator 422/500, Train metric: 0.4667
# Estimator 423/500, Train metric: 0.4647
# Estimator 424/500, Train metric: 0.4647
# Estimator 425/500, Train metric: 0.4639
# Estimator 426/500, Train metric: 0.4661
# Estimator 427/500, Train metric: 0.4684
# Estimator 428/500, Train metric: 0.4644
# Estimator 429/500, Train metric: 0.4636
# Estimator 430/500, Train metric: 0.4648
# Estimator 431/500, Train metric: 0.4685
# Estimator 432/500, Train metric: 0.4642
# Estimator 433/500, Train metric: 0.4634
# Estimator 434/500, Train metric: 0.4634
# Estimator 435/500, Train metric: 0.4643
# Estimator 436/500, Train metric: 0.4642
# Estimator 437/500, Train metric: 0.4637
# Estimator 438/500, Train metric: 0.4627
# Estimator 439/500, Train metric: 0.4626
# Estimator 440/500, Train metric: 0.4624
# Estimator 441/500, Train metric: 0.4619
# Estimator 442/500, Train metric: 0.4628
# Estimator 443/500, Train metric: 0.4611
# Estimator 444/500, Train metric: 0.4626
# Estimator 445/500, Train metric: 0.4619
# Estimator 446/500, Train metric: 0.4626
# Estimator 447/500, Train metric: 0.4641
# Estimator 448/500, Train metric: 0.4622
# Estimator 449/500, Train metric: 0.4652
# Estimator 450/500, Train metric: 0.4655
# Estimator 451/500, Train metric: 0.4628
# Estimator 452/500, Train metric: 0.4632
# Estimator 453/500, Train metric: 0.4631
# Estimator 454/500, Train metric: 0.4635
# Estimator 455/500, Train metric: 0.4639
# Estimator 456/500, Train metric: 0.4658
# Estimator 457/500, Train metric: 0.4609
# Estimator 458/500, Train metric: 0.4598
# Estimator 459/500, Train metric: 0.4638
# Estimator 460/500, Train metric: 0.4661
# Estimator 461/500, Train metric: 0.4660
# Estimator 462/500, Train metric: 0.4674
# Estimator 463/500, Train metric: 0.4674
# Estimator 464/500, Train metric: 0.4698
# Estimator 465/500, Train metric: 0.4667
# Estimator 466/500, Train metric: 0.4670
# Estimator 467/500, Train metric: 0.4682
# Estimator 468/500, Train metric: 0.4678
# Estimator 469/500, Train metric: 0.4670
# Estimator 470/500, Train metric: 0.4657
# Estimator 471/500, Train metric: 0.4623
# Estimator 472/500, Train metric: 0.4620
# Estimator 473/500, Train metric: 0.4620
# Estimator 474/500, Train metric: 0.4608
# Estimator 475/500, Train metric: 0.4609
# Estimator 476/500, Train metric: 0.4609
# Estimator 477/500, Train metric: 0.4618
# Estimator 478/500, Train metric: 0.4612
# Estimator 479/500, Train metric: 0.4613
# Estimator 480/500, Train metric: 0.4613
# Estimator 481/500, Train metric: 0.4600
# Estimator 482/500, Train metric: 0.4599
# Estimator 483/500, Train metric: 0.4602
# Estimator 484/500, Train metric: 0.4609
# Estimator 485/500, Train metric: 0.4569
# Estimator 486/500, Train metric: 0.4578
# Estimator 487/500, Train metric: 0.4560
# Estimator 488/500, Train metric: 0.4572
# Estimator 489/500, Train metric: 0.4570
# Estimator 490/500, Train metric: 0.4571
# Estimator 491/500, Train metric: 0.4569
# Estimator 492/500, Train metric: 0.4570
# Estimator 493/500, Train metric: 0.4565
# Estimator 494/500, Train metric: 0.4566
# Estimator 495/500, Train metric: 0.4581
# Estimator 496/500, Train metric: 0.4582
# Estimator 497/500, Train metric: 0.4604
# Estimator 498/500, Train metric: 0.4578
# Estimator 499/500, Train metric: 0.4573
# Mean Squared Error: 6.32
#         Mean    StdDev  Actual
# 0  32.847939  3.574280    34.0
# 1  36.492413  3.387842    36.0
# 2  35.004215  2.787475    36.0
# 3  34.692562  2.879506    35.0
# 4  41.732891  3.437613    44.6

# %%
generate_and_save_plots(predictions_PGBM_df, y_test, "./drive/MyDrive/Concrete_ml/PGBM_Prob.xlsx")
# Out:
# Excel file saved at ./drive/MyDrive/Concrete_ml/PGBM_Prob.xlsx

# %% [markdown]
# # **IBUG Installation**

# %%
# Clone the repository
# !git clone https://github.com/jjbrophy47/ibug.git
# %cd ibug

# Build extensions if needed
# !python setup.py build_ext --inplace

# Install the package
# !pip install .

# Verify installation
try:
    from ibug import IBUGWrapper
    print("IBUGWrapper imported successfully!")
except ImportError as e:
    print("Error importing IBUGWrapper:", e)
# Out:
# Cloning into 'ibug'...
# remote: Enumerating objects: 1763, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 1763 (delta 18), reused 15 (delta 4), pack-reused 1726 (from 1)
# Receiving objects: 100% (1763/1763), 1.31 MiB | 4.98 MiB/s, done.
# Resolving deltas: 100% (967/967), done.
# /content/ibug
# Compiling ibug/parsers/_tree32.pyx because it changed.
# Compiling ibug/parsers/_tree64.pyx because it changed.
# [1/2] Cythonizing ibug/parsers/_tree32.pyx
# performance hint: ibug/parsers/_tree32.pyx:84:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:112:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:140:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:238:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:266:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:312:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:344:47: Exception check after calling '_initialize_node' will always require the GIL to be acquired. Declare '_initialize_node' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:352:48: Exception check after calling '_add_node' will always require the GIL to be acquired. Declare '_add_node' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:355:49: Exception check after calling '_add_node' will always require the GIL to be acquired. Declare '_add_node' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree32.pyx:400:33: Exception check after calling '_get_leaf_values' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_values' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_values' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:401:33: Exception check after calling '_get_leaf_values' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_values' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_values' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:417:34: Exception check after calling '_get_leaf_weights' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_weights' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_weights' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:418:34: Exception check after calling '_get_leaf_weights' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_weights' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_weights' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:434:33: Exception check after calling '_get_leaf_depths' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_depths' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_depths' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:435:33: Exception check after calling '_get_leaf_depths' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_depths' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_depths' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:464:21: Exception check after calling '_dealloc' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_dealloc' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_dealloc' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree32.pyx:465:21: Exception check after calling '_dealloc' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_dealloc' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_dealloc' to allow an error code to be returned.
# [2/2] Cythonizing ibug/parsers/_tree64.pyx
# performance hint: ibug/parsers/_tree64.pyx:93:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:121:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:149:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:247:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:275:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:321:43: Exception check after calling '_test_threshold' will always require the GIL to be acquired. Declare '_test_threshold' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:353:47: Exception check after calling '_initialize_node' will always require the GIL to be acquired. Declare '_initialize_node' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:361:48: Exception check after calling '_add_node' will always require the GIL to be acquired. Declare '_add_node' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:364:49: Exception check after calling '_add_node' will always require the GIL to be acquired. Declare '_add_node' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# performance hint: ibug/parsers/_tree64.pyx:409:33: Exception check after calling '_get_leaf_values' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_values' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_values' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:410:33: Exception check after calling '_get_leaf_values' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_values' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_values' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:426:34: Exception check after calling '_get_leaf_weights' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_weights' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_weights' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:427:34: Exception check after calling '_get_leaf_weights' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_weights' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_weights' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:443:33: Exception check after calling '_get_leaf_depths' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_depths' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_depths' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:444:33: Exception check after calling '_get_leaf_depths' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_get_leaf_depths' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_get_leaf_depths' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:473:21: Exception check after calling '_dealloc' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_dealloc' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_dealloc' to allow an error code to be returned.
# performance hint: ibug/parsers/_tree64.pyx:474:21: Exception check after calling '_dealloc' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare '_dealloc' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on '_dealloc' to allow an error code to be returned.
# running build_ext
# building 'ibug.parsers._tree32' extension
# creating build/temp.linux-x86_64-cpython-311/ibug/parsers
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c ibug/parsers/_tree32.c -o build/temp.linux-x86_64-cpython-311/ibug/parsers/_tree32.o
# In file included from /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from ibug/parsers/_tree32.c:1257:
# /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# creating build/lib.linux-x86_64-cpython-311/ibug/parsers
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/ibug/parsers/_tree32.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/ibug/parsers/_tree32.cpython-311-x86_64-linux-gnu.so
# building 'ibug.parsers._tree64' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/numpy/core/include -I/usr/include/python3.11 -c ibug/parsers/_tree64.c -o build/temp.linux-x86_64-cpython-311/ibug/parsers/_tree64.o
# In file included from /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from ibug/parsers/_tree64.c:1257:
# /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/ibug/parsers/_tree64.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/ibug/parsers/_tree64.cpython-311-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-311/ibug/parsers/_tree32.cpython-311-x86_64-linux-gnu.so -> ibug/parsers
# copying build/lib.linux-x86_64-cpython-311/ibug/parsers/_tree64.cpython-311-x86_64-linux-gnu.so -> ibug/parsers
# Processing /content/ibug
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (1.26.4)
# Collecting uncertainty-toolbox>=0.1.0 (from ibug==0.0.12)
#   Downloading uncertainty_toolbox-0.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: joblib>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (1.6.1)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (1.14.1)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (2.2.2)
# Requirement already satisfied: Cython>=0.29.23 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (3.0.12)
# Requirement already satisfied: xgboost>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from ibug==0.0.12) (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->ibug==0.0.12) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->ibug==0.0.12) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->ibug==0.0.12) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.5.0->ibug==0.0.12) (3.6.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from uncertainty-toolbox>=0.1.0->ibug==0.0.12) (3.10.0)
# Requirement already satisfied: tqdm>=4.54.0 in /usr/local/lib/python3.11/dist-packages (from uncertainty-toolbox>=0.1.0->ibug==0.0.12) (4.67.1)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost>=1.6.1->ibug==0.0.12) (2.21.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->uncertainty-toolbox>=0.1.0->ibug==0.0.12) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.3->ibug==0.0.12) (1.17.0)
# Downloading uncertainty_toolbox-0.1.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: ibug
#   Building wheel for ibug (pyproject.toml) ... done
#   Created wheel for ibug: filename=ibug-0.0.12-cp311-cp311-linux_x86_64.whl size=1411626 sha256=71c522cdd5c3a6f702380c11e4392852cc2cf7469a9e47b528f9e2e125af9a34
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u54msrtf/wheels/e8/98/c6/e234d962a0f9a159d3b0fc51d90429532bfe6647099336e8e3
# Successfully built ibug
# Installing collected packages: uncertainty-toolbox, ibug
# Successfully installed ibug-0.0.12 uncertainty-toolbox-0.1.1
# IBUGWrapper imported successfully!

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3)

y_train = y_train.to_numpy()
y_val = y_val.to_numpy()

# %% [markdown]
# # **Probabilistic distributions using LGBM**

# %%
# Assume hyperparameter tuning has been done and best_params are obtained
best_params = get_best_model_params(best_scores_autosampler, 'LightGBM')

# Initialize and train the LightGBM regressor using the best_params
model = LGBMRegressor(**best_params)
model.fit(X_train, y_train)

# Extend the trained model into a probabilistic predictor using IBUGWrapper
prob_model = IBUGWrapper().fit(model, X_train, y_train, X_val=X_val, y_val=y_val)

# Use the model to predict the probabilistic distribution on the test data.
location, scale = prob_model.pred_dist(X_test)

# Optionally, to also get the k-nearest training indices and their values used in modeling
location, scale, train_idxs, train_vals = prob_model.pred_dist(X_test, return_kneighbors=True)

dev = scale**0.5
# Create a DataFrame for clarity
predictions_LGBM_df = pd.DataFrame({
    'Mean': location,
    'StdDev': dev,
    'Actual': y_test,
})

print(predictions_LGBM_df.head())
# Out:
#         Mean    StdDev  Actual
# 0  31.881335  1.963382    34.0
# 1  34.631388  1.715456    36.0
# 2  34.714338  1.079903    36.0
# 3  36.315959  1.744427    35.0
# 4  41.027078  2.053486    44.6

# %%
# %cd ..
# Out:
# /

# %%
generate_and_save_plots(predictions_LGBM_df, y_test, "./content/drive/MyDrive/Concrete_ml/LGBM_Prob.xlsx")
# Out:
# Excel file saved at ./content/drive/MyDrive/Concrete_ml/LGBM_Prob.xlsx

# %% [markdown]
# # **Probabilistic distributions using XGBoost**

# %%
# Assume hyperparameter tuning has been done and best_params are obtained
best_params = get_best_model_params(best_scores_autosampler, 'XGBoost')

best_params['reg_alpha'] = 0
best_params['scale_pos_weight'] = 1
best_params['base_score'] = 0.5

# Initialize and train the XGBoost regressor using the best_params
model = XGBRegressor(**best_params)
model.fit(X_train, y_train)

# Extend the trained model into a probabilistic predictor using IBUGWrapper
prob_model = IBUGWrapper().fit(model, X_train, y_train, X_val=X_val, y_val=y_val)

# Use the model to predict the probabilistic distribution on the test data.
# This returns the predicted mean (location) and uncertainty (scale, variance proxy)
location, scale = prob_model.pred_dist(X_test)

# Optionally, to also get the k-nearest training indices and their values used in modeling
location, scale, train_idxs, train_vals = prob_model.pred_dist(X_test, return_kneighbors=True)

# Calculate the standard deviation from the variance (scale)
std_dev = scale ** 0.5

# Create a DataFrame for clarity
predictions_XGB_df = pd.DataFrame({
    'Mean': location,
    'StdDev': std_dev,
    'Actual': y_test
})

print(predictions_XGB_df.head())
# Out:
#         Mean    StdDev  Actual
# 0  32.805756  1.840347    34.0
# 1  35.787136  2.477010    36.0
# 2  34.889946  1.579555    36.0
# 3  35.339767  2.380858    35.0
# 4  43.588402  3.152893    44.6

# %%
generate_and_save_plots(predictions_LGBM_df, y_test, "./content/drive/MyDrive/Concrete_ml/XGB_Prob.xlsx")
# Out:
# Excel file saved at ./content/drive/MyDrive/Concrete_ml/XGB_Prob.xlsx

# %% [markdown]
# # **Matrix Evaulation**

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
folder_path = "/content/drive/MyDrive/Concrete_ml"
excel_path = os.path.join(folder_path, "/content/drive/MyDrive/Concrete_ml/Matrix Evaluation.xlsx")
with pd.ExcelWriter(excel_path, engine='xlsxwriter') as writer:
    plot_metrics_and_save_to_excel(writer, predictions_NGB_df, y_test, 'NGBoost')
    plot_metrics_and_save_to_excel(writer, predictions_PGBM_df, y_test, 'PGBM')
    plot_metrics_and_save_to_excel(writer, predictions_LGBM_df, y_test, 'LGBM')
    plot_metrics_and_save_to_excel(writer, predictions_XGB_df, y_test, 'XGBoost')
