# %% [markdown]
# # **Start Section:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.5.2
# !pip install bayesian-optimization
# !pip install optuna
# !pip install catboost
# !pip install gpboost
# !pip install shap
# !pip install ngboost
# !pip install dask[dataframe]
# !pip install torch seaborn
# !pip install lightgbm
# !pip install xgboost
# !pip install lime
# !pip install interpret
# !pip install optunahub
# !pip install cmaes
# !pip install plotly kaleido
# !pip install openpyxl
# !pip install -U kaleido
# !pip install properscoring
# !pip install XlsxWriter
# !pip install cython
# !pip install pgbm
# !pip install torch
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.5.0)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 43.3 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.5.2
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-2.0.3-py3-none-any.whl.metadata (9.0 kB)
# Collecting colorama<0.5.0,>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.5.0)
# Downloading bayesian_optimization-2.0.3-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-2.0.3 colorama-0.4.6
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 8.7 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 15.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.9 alembic-1.14.1 colorlog-6.9.0 optuna-4.2.1
# Collecting catboost
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Collecting gpboost
#   Downloading gpboost-1.5.6-py3-none-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from gpboost) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from gpboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.13.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.5.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from gpboost) (4.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (1.14.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->gpboost) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->gpboost) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->gpboost) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->gpboost) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna->gpboost) (3.0.2)
# Downloading gpboost-1.5.6-py3-none-manylinux1_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.5 MB/s eta 0:00:00
# Installing collected packages: gpboost
# Successfully installed gpboost-1.5.6
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->shap) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Collecting ngboost
#   Downloading ngboost-0.5.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting lifelines>=0.25 (from ngboost)
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.26.4)
# Collecting scikit-learn<2.0,>=1.6 (from ngboost)
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.13.1)
# Requirement already satisfied: tqdm>=4.3 in /usr/local/lib/python3.11/dist-packages (from ngboost) (4.67.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (1.7.0)
# Collecting autograd-gamma>=0.3 (from lifelines>=0.25->ngboost)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines>=0.25->ngboost)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (3.5.0)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines>=0.25->ngboost)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines>=0.25->ngboost) (1.17.0)
# Downloading ngboost-0.5.5-py3-none-any.whl (33 kB)
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 7.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 88.1 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 8.1 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4031 sha256=04c402a83e1ce105cc0b98a625750d4569cc9eb98af27f537b1965ca83f911a5
#   Stored in directory: /root/.cache/pip/wheels/8b/67/f4/2caaae2146198dcb824f31a303833b07b14a5ec863fb3acd7b
# Successfully built autograd-gamma
# Installing collected packages: interface-meta, scikit-learn, autograd-gamma, formulaic, lifelines, ngboost
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# Successfully installed autograd-gamma-0.5.0 formulaic-1.1.1 interface-meta-1.3.0 lifelines-0.30.0 ngboost-0.5.5 scikit-learn-1.6.1
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2024.11.2)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.6.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2.2.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.1.19)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 43.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.13.1)
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.2.18)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=bc205b17c99062ceff362b3b705fa4cc7cac681b5d9dfb7ad7c4d136f01cfadf
#   Stored in directory: /root/.cache/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1
# Collecting interpret
#   Downloading interpret-0.6.9-py3-none-any.whl.metadata (1.0 kB)
# Collecting interpret-core==0.6.9 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading interpret_core-0.6.9-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.26.4)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.18.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.4.2)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.9.5)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (6.17.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (7.34.0)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.24.1)
# Collecting SALib>=1.3.3 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading salib-1.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: shap>=0.28.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.46.0)
# Collecting dill>=0.2.5 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting aplr>=10.6.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading aplr-10.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting dash>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting dash-core-components>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-html-components>=1.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-table>=4.1.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 38.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gevent>=1.3.6 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading gevent-24.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.32.3)
# Collecting Flask<3.1,>=1.0.4 (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.12.2)
# Collecting retrying (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (75.1.0)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.1.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (24.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.7.1)
# Collecting jedi>=0.16 (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (9.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2025.1.31)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.10.0)
# Collecting multiprocess (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret)
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18.1->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.5.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.61.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (5.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->interpret-core==0.6.9->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (3.21.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.9->interpret) (4.3.6)
# Downloading interpret-0.6.9-py3-none-any.whl (1.4 kB)
# Downloading interpret_core-0.6.9-py3-none-any.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 87.1 MB/s eta 0:00:00
# Downloading aplr-10.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 91.7 MB/s eta 0:00:00
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 96.8 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.1 MB/s eta 0:00:00
# Downloading gevent-24.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 82.1 MB/s eta 0:00:00
# Downloading salib-1.5.1-py3-none-any.whl (778 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 39.2 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.4 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.6 MB/s eta 0:00:00
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 16.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py311-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 12.0 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 17.7 MB/s eta 0:00:00
# Building wheels for collected packages: dash-cytoscape
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Created wheel for dash-cytoscape: filename=dash_cytoscape-1.0.2-py3-none-any.whl size=4010716 sha256=852b5aedeac78e6f8074b7a7c885027369e8b3d7eafa1dd1539033867ef91c74
#   Stored in directory: /root/.cache/pip/wheels/99/b1/ab/6c999ab288b4849d372e23c0a8f6ece7edb7ffeb8c97959ab0
# Successfully built dash-cytoscape
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zope.interface, zope.event, Werkzeug, retrying, jedi, dill, aplr, multiprocess, gevent, Flask, SALib, interpret-core, dash, dash-cytoscape, interpret
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
# Successfully installed Flask-3.0.3 SALib-1.5.1 Werkzeug-3.0.6 aplr-10.8.0 dash-2.18.2 dash-core-components-2.0.0 dash-cytoscape-1.0.2 dash-html-components-2.0.0 dash-table-5.0.0 dill-0.3.9 gevent-24.11.1 interpret-0.6.9 interpret-core-0.6.9 jedi-0.19.2 multiprocess-0.70.17 retrying-1.3.4 zope.event-5.0 zope.interface-7.2
# Collecting optunahub
#   Downloading optunahub-0.2.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting ga4mp (from optunahub)
#   Downloading ga4mp-2.0.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optunahub) (4.2.1)
# Collecting PyGithub>=1.59 (from optunahub)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting pynacl>=1.4.0 (from PyGithub>=1.59->optunahub)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (2.3.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (1.2.18)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (1.14.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->optunahub) (1.3.9)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->PyGithub>=1.59->optunahub) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optunahub) (3.1.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->PyGithub>=1.59->optunahub) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub>=1.59->optunahub) (2.22)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna->optunahub) (3.0.2)
# Downloading optunahub-0.2.0-py3-none-any.whl (11 kB)
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 9.2 MB/s eta 0:00:00
# Downloading ga4mp-2.0.4-py3-none-any.whl (15 kB)
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 30.2 MB/s eta 0:00:00
# Installing collected packages: ga4mp, pynacl, PyGithub, optunahub
# Successfully installed PyGithub-2.6.1 ga4mp-2.0.4 optunahub-0.2.0 pynacl-1.5.0
# Collecting cmaes
#   Downloading cmaes-0.11.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from cmaes) (1.26.4)
# Downloading cmaes-0.11.1-py3-none-any.whl (35 kB)
# Installing collected packages: cmaes
# Successfully installed cmaes-0.11.1
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.8 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Collecting properscoring
#   Downloading properscoring-0.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.13.1)
# Downloading properscoring-0.1-py2.py3-none-any.whl (23 kB)
# Installing collected packages: properscoring
# Successfully installed properscoring-0.1
# Collecting XlsxWriter
#   Downloading XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Downloading XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-3.2.2
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Collecting pgbm
#   Downloading pgbm-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pgbm) (1.6.1)
# Collecting ninja>=1.10.2.2 (from pgbm)
#   Downloading ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.11/dist-packages (from pgbm) (0.61.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->pgbm) (0.44.0)
# Requirement already satisfied: numpy<2.2,>=1.24 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->pgbm) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (3.5.0)
# Downloading pgbm-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 40.3 MB/s eta 0:00:00
# Downloading ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 24.7 MB/s eta 0:00:00
# Installing collected packages: ninja, pgbm
# Successfully installed ninja-1.11.1.3 pgbm-2.3.0
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from optuna.samplers import BaseSampler
from optuna.samplers import GridSampler
from optuna.samplers import TPESampler
from optuna.samplers import PartialFixedSampler
from optuna.samplers import CmaEsSampler
from optuna.samplers import QMCSampler
from optuna.samplers import NSGAIIISampler
from optuna.samplers import NSGAIISampler
from optuna.samplers import BruteForceSampler
from optuna.samplers import GPSampler
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
import properscoring as ps
import io
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
warnings.filterwarnings('ignore')
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py311_cu124/split_decision...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/split_decision/build.ninja...
# Building extension module split_decision...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module split_decision...
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# No modifications detected for re-loaded extension module split_decision, skipping build step...
# Loading extension module split_decision...

# %%
train_data_path = "./drive/MyDrive/Concrete_ml/train.csv"
test_data_path = "./drive/MyDrive/Concrete_ml/test.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (189, 8)
# First 5 rows of training data:
#          C    mp     FA      CA       F       W_P    Adm    str
# 0  280.80  70.2  858.0  1183.0    0.00  0.450000  0.610  21.56
# 1  372.15   0.0  975.0   525.0   52.85  0.493081  7.000  34.00
# 2  360.00  75.0  975.0   525.0   40.00  0.509722  7.000  28.00
# 3  364.30   0.0  975.0   525.0  110.40  0.503706  7.000  42.00
# 4  315.00  31.5  780.0  1110.0    0.00  0.370000  5.355  25.82
#
# Shape of test data: (95, 8)
# First 5 rows of test data:
#          C     mp     FA     CA      F       W_P   Adm   str
# 0  364.30    0.0  975.0  525.0  60.40  0.503706   7.0  34.0
# 1  344.30   75.0  975.0  525.0  55.40  0.532965   7.0  36.0
# 2  390.00    0.0  975.0  525.0  60.00  0.470513   7.0  36.0
# 3  352.15   75.0  975.0  525.0  47.85  0.521085   7.0  35.0
# 4  400.00  160.0  801.0  801.0  40.00  0.300000  10.3  44.6

# %%
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
x_test= X_test
print("\nShape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (189, 7)
# Shape of y_train: (189,)
# Shape of X_test: (95, 7)
# Shape of y_test: (95,)

# %%
# Apply z-score normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Print the first five rows of the normalized data
print("\nFirst five rows of normalized X_train:")
print(X_train[:5])

print("\nFirst five rows of normalized X_test:")
print(X_test[:5])
# Out:
# First five rows of normalized X_train:
# [[-1.56879184  0.95792014 -0.09685034  1.33138508 -0.85369002  0.16810471
#   -0.08799752]
#  [ 0.40300047 -0.7708921   0.73537613 -0.93459372  0.061075    0.78285857
#   -0.0664621 ]
#  [ 0.14074238  1.07612953  0.73537613 -0.93459372 -0.16134185  1.020321
#   -0.0664621 ]
#  [ 0.233558   -0.7708921   0.73537613 -0.93459372  1.05719093  0.93447436
#   -0.0664621 ]
#  [-0.83058388  0.00485698 -0.65166799  1.07999229 -0.85369002 -0.97347298
#   -0.07200604]]
#
# First five rows of normalized X_test:
# [[ 0.233558   -0.7708921   0.73537613 -0.93459372  0.19175572  0.93447436
#   -0.0664621 ]
#  [-0.19814256  1.07612953  0.73537613 -0.93459372  0.1052122   1.35199213
#   -0.0664621 ]
#  [ 0.78829322 -0.7708921   0.73537613 -0.93459372  0.18483223  0.4608195
#   -0.0664621 ]
#  [-0.02870009  1.07612953  0.73537613 -0.93459372 -0.02546852  1.18246784
#   -0.0664621 ]
#  [ 1.0041435   3.1694207  -0.50229401  0.01587763 -0.16134185 -1.97235346
#   -0.05534052]]

# %%
feature_names = ['C', 'mp', 'FA', 'CA', 'F', 'W_P', 'Adm']

# %%
def get_best_model_params(results, model_name):
    # Map model names to dictionary keys, assuming keys are strings like 'XGBoost' and not objects
    model_keys = {
        'LightGBM': 'LightGBM',
        'XGBoost': 'XGBoost',
        'GPBoost': 'GPBoost',
        'NGBoost': 'NGBoost',
        'PGBMR' : 'PGBMR',
        'PGBM' : 'PGBM'
    }

    # Ensure the requested model name is valid
    if model_name not in model_keys:
        raise ValueError(f"Model name '{model_name}' is not recognized. Available models are: {list(model_keys.keys())}")

    # Filter out entries for the specified model
    model_entries = {key: value for key, value in results.items() if key[0] == model_keys[model_name]}

    # Find the entry with the best (lowest) 'best_score'
    best_entry_key, best_entry_value = min(model_entries.items(), key=lambda item: item[1]['best_score'])

    # Return the best hyperparameters
    return best_entry_value['best_params']

# %% [markdown]
# # **Hyperparameter Tuning using Autosampler Optuna**

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Define objective and metric functions for PGBM
def mseloss_objective(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss


def hyperparameter_tuning_all(X_train, y_train, X_test, y_test):

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)


    models = {
        'XGBoost': (XGBRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'n_estimators': [100, 200, 300, 400, 500],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9]
        }),
        'GPBoost': (GPBoostRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'n_estimators': [100, 200, 300, 400, 500],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'alpha': [0.1, 0.5, 1.0],
            'lambda': [0.1, 0.5, 1.0],
            'verbose': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'n_estimators': [100, 200, 300, 400, 500],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'verbose': [-1]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [1, 5, 10],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False]
        }),
        'PGBM': (PGBM, {}) # PGBM is handled separately
    }

    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}

    for model_name, (model_class, param_space) in models.items():
        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            try:
                sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
                study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

                if model_name == 'PGBM':
                    def pgbm_objective(trial):
                        params = {
                            'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 1.0),
                            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
                            'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'n_estimators': trial.suggest_int('n_estimators', 50, 500),
                            'verbose': 0,
                            'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
                            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
                            'tree_correlation': trial.suggest_float('tree_correlation', 0.0, 0.5)
                        }

                        model = PGBM()


                        model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=params)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(pgbm_objective, n_trials=50)
                else:
                    def objective(trial, model_name, model_class, param_space):
                        params = {}
                        for key, values in param_space.items():
                            if isinstance(values, list):
                                params[key] = trial.suggest_categorical(key, values)
                            elif isinstance(values, tuple):
                                if len(values) == 2:
                                    params[key] = trial.suggest_float(key, values[0], values[1])
                                elif len(values) == 3 and isinstance(values[2], bool) and values[2]:
                                    params[key] = trial.suggest_int(key, values[0], values[1])
                                else:
                                    raise ValueError(f"Invalid parameter range for {key}")

                        model = model_class(**params)

                        model.fit(X_train, y_train)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(lambda trial: objective(trial, model_name, model_class, param_space), n_trials=50)

                best_params = study.best_params
                best_model = model_class(**best_params) if model_name != 'PGBM' else PGBM()
                if model_name == 'PGBM':
                    best_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params,)
                else:
                    best_model.fit(X_train, y_train)
                y_pred = best_model.predict(X_test)

                mse = mean_squared_error(y_test, y_pred)
                rmse = np.sqrt(mse)
                corr_coef = np.corrcoef(y_test, y_pred)[0, 1]

                best_scores[(model_name, pruner_name)] = {
                    'best_score': mse,
                    'best_params': best_params,
                    'test_mse': mse,
                    'test_rmse': rmse,
                    'test_corr_coef': corr_coef,
                    'pruner': pruner_name
                }
                print(f"Best MSE for {model_name} with {pruner_name}: {mse} with params: {best_params}")
                print(f"Best RMSE for {model_name} with {pruner_name}: {rmse}")
                print(f"Correlation Coefficient for {model_name} with {pruner_name}: {corr_coef}")
            except Exception as e:
                print(f"Failed to run Optuna for {model_name} with {pruner_name}. Error: {e}")

    if best_scores:
        best_model_name, best_pruner_name = min(best_scores, key=lambda k: best_scores[k]['test_mse'])
        best_model_info = best_scores[(best_model_name, best_pruner_name)]
        print(f"\nBest model on test data: {best_model_name} with {best_pruner_name}")
        print(f"Test MSE: {best_model_info['test_mse']}")
        print(f"Test RMSE: {best_model_info['test_rmse']}")
        print(f"Correlation Coefficient: {best_model_info['test_corr_coef']}")
        print(f"Best Parameters: {best_model_info['best_params']}")
        print(f"Pruner Used: {best_model_info['pruner']}")
    else:
        print("No valid model configurations found.")

    return best_scores

# Example usage
best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test)
# Out:
# Running Optuna for XGBoost with MedianPruner...
# Best MSE for XGBoost with MedianPruner: 7.922596052961659 with params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 400, 'min_child_weight': 3, 'gamma': 0.5, 'subsample': 0.6, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with MedianPruner: 2.8147106517298823
# Correlation Coefficient for XGBoost with MedianPruner: 0.9596603333804019
# Running Optuna for XGBoost with NopPruner...
# Best MSE for XGBoost with NopPruner: 7.56538567018717 with params: {'learning_rate': 0.15, 'max_depth': 7, 'n_estimators': 100, 'min_child_weight': 1, 'gamma': 0.5, 'subsample': 0.8, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with NopPruner: 2.7505246172661626
# Correlation Coefficient for XGBoost with NopPruner: 0.9621439326535741
# Running Optuna for XGBoost with PatientPruner...
# Best MSE for XGBoost with PatientPruner: 7.884869680408798 with params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 5, 'gamma': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.7}
# Best RMSE for XGBoost with PatientPruner: 2.8080010114686207
# Correlation Coefficient for XGBoost with PatientPruner: 0.9599596852633636
# Running Optuna for XGBoost with PercentilePruner...
# Best MSE for XGBoost with PercentilePruner: 8.017891274277664 with params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'min_child_weight': 3, 'gamma': 1, 'subsample': 0.6, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with PercentilePruner: 2.8315881187555623
# Correlation Coefficient for XGBoost with PercentilePruner: 0.9594816172187036
# Running Optuna for XGBoost with SuccessiveHalvingPruner...
# Best MSE for XGBoost with SuccessiveHalvingPruner: 7.493234457918664 with params: {'learning_rate': 0.15, 'max_depth': 3, 'n_estimators': 500, 'min_child_weight': 1, 'gamma': 0.5, 'subsample': 0.7, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with SuccessiveHalvingPruner: 2.737377295499958
# Correlation Coefficient for XGBoost with SuccessiveHalvingPruner: 0.9622377376382778
# Running Optuna for XGBoost with HyperbandPruner...
# Best MSE for XGBoost with HyperbandPruner: 7.637529832056911 with params: {'learning_rate': 0.15, 'max_depth': 7, 'n_estimators': 200, 'min_child_weight': 1, 'gamma': 1, 'subsample': 0.8, 'colsample_bytree': 0.5}
# Best RMSE for XGBoost with HyperbandPruner: 2.763608118394667
# Correlation Coefficient for XGBoost with HyperbandPruner: 0.9618739336084581
# Running Optuna for XGBoost with ThresholdPruner...
# Best MSE for XGBoost with ThresholdPruner: 7.872770401242194 with params: {'learning_rate': 0.15, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 5, 'gamma': 0.5, 'subsample': 0.9, 'colsample_bytree': 0.9}
# Best RMSE for XGBoost with ThresholdPruner: 2.805845755069618
# Correlation Coefficient for XGBoost with ThresholdPruner: 0.9597127583571825
# Running Optuna for XGBoost with WilcoxonPruner...
# Best MSE for XGBoost with WilcoxonPruner: 7.762305039008369 with params: {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'min_child_weight': 3, 'gamma': 0, 'subsample': 0.6, 'colsample_bytree': 0.9}
# Best RMSE for XGBoost with WilcoxonPruner: 2.7860913551081503
# Correlation Coefficient for XGBoost with WilcoxonPruner: 0.9604815611220123
# Running Optuna for GPBoost with MedianPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with MedianPruner: 6.501198008286671 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'alpha': 0.1, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with MedianPruner: 2.5497446947266447
# Correlation Coefficient for GPBoost with MedianPruner: 0.9668789961471742
# Running Optuna for GPBoost with NopPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with NopPruner: 6.5798878786251525 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 300, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'alpha': 0.5, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with NopPruner: 2.5651292128516943
# Correlation Coefficient for GPBoost with NopPruner: 0.9664846026080294
# Running Optuna for GPBoost with PatientPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with PatientPruner: 6.888425210118871 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.9, 'alpha': 0.5, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with PatientPruner: 2.6245809589568525
# Correlation Coefficient for GPBoost with PatientPruner: 0.964888828354819
# Running Optuna for GPBoost with PercentilePruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with PercentilePruner: 6.626961600369569 with params: {'learning_rate': 0.15, 'max_depth': 5, 'n_estimators': 100, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'alpha': 1.0, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with PercentilePruner: 2.574288561985538
# Correlation Coefficient for GPBoost with PercentilePruner: 0.9661961763000706
# Running Optuna for GPBoost with SuccessiveHalvingPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# Best MSE for GPBoost with SuccessiveHalvingPruner: 6.869774157059443 with params: {'learning_rate': 0.15, 'max_depth': 3, 'n_estimators': 500, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.7, 'colsample_bytree': 0.5, 'alpha': 0.5, 'lambda': 0.5, 'verbose': -1}
# Best RMSE for GPBoost with SuccessiveHalvingPruner: 2.621025401834069
# Correlation Coefficient for GPBoost with SuccessiveHalvingPruner: 0.964975306779623
# Running Optuna for GPBoost with HyperbandPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# Best MSE for GPBoost with HyperbandPruner: 6.472878269017162 with params: {'learning_rate': 0.15, 'max_depth': 3, 'n_estimators': 200, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.5, 'alpha': 0.5, 'lambda': 0.1, 'verbose': -1}
# Best RMSE for GPBoost with HyperbandPruner: 2.54418518764204
# Correlation Coefficient for GPBoost with HyperbandPruner: 0.9672213706525883
# Running Optuna for GPBoost with ThresholdPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# Best MSE for GPBoost with ThresholdPruner: 6.522874447410504 with params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'alpha': 0.1, 'lambda': 0.5, 'verbose': -1}
# Best RMSE for GPBoost with ThresholdPruner: 2.553991865180957
# Correlation Coefficient for GPBoost with ThresholdPruner: 0.9667613385600534
# Running Optuna for GPBoost with WilcoxonPruner...
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# [GPBoost] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [GPBoost] [Warning] lambda_l2 is set with lambda=0.5, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.5
# ...
# Estimator 121/500, Train metric: 1.7733
# Estimator 122/500, Train metric: 1.7571
# Estimator 123/500, Train metric: 1.7478
# Estimator 124/500, Train metric: 1.7476
# Estimator 125/500, Train metric: 1.7463
# Estimator 126/500, Train metric: 1.7423
# Estimator 127/500, Train metric: 1.7348
# Estimator 128/500, Train metric: 1.7240
# Estimator 129/500, Train metric: 1.7153
# Estimator 130/500, Train metric: 1.7087
# Estimator 131/500, Train metric: 1.7042
# Estimator 132/500, Train metric: 1.6865
# Estimator 133/500, Train metric: 1.6772
# Estimator 134/500, Train metric: 1.6726
# Estimator 135/500, Train metric: 1.6652
# Estimator 136/500, Train metric: 1.6599
# Estimator 137/500, Train metric: 1.6539
# Estimator 138/500, Train metric: 1.6471
# Estimator 139/500, Train metric: 1.6397
# Estimator 140/500, Train metric: 1.6339
# Estimator 141/500, Train metric: 1.6310
# Estimator 142/500, Train metric: 1.6321
# Estimator 143/500, Train metric: 1.6313
# Estimator 144/500, Train metric: 1.6259
# Estimator 145/500, Train metric: 1.6157
# Estimator 146/500, Train metric: 1.6137
# Estimator 147/500, Train metric: 1.6048
# Estimator 148/500, Train metric: 1.5982
# Estimator 149/500, Train metric: 1.5964
# Estimator 150/500, Train metric: 1.5811
# Estimator 151/500, Train metric: 1.5785
# Estimator 152/500, Train metric: 1.5698
# Estimator 153/500, Train metric: 1.5635
# Estimator 154/500, Train metric: 1.5560
# Estimator 155/500, Train metric: 1.5522
# Estimator 156/500, Train metric: 1.5452
# Estimator 157/500, Train metric: 1.5373
# Estimator 158/500, Train metric: 1.5332
# Estimator 159/500, Train metric: 1.5316
# Estimator 160/500, Train metric: 1.5183
# Estimator 161/500, Train metric: 1.5128
# Estimator 162/500, Train metric: 1.5051
# Estimator 163/500, Train metric: 1.5017
# Estimator 164/500, Train metric: 1.4997
# Estimator 165/500, Train metric: 1.4921
# Estimator 166/500, Train metric: 1.4879
# Estimator 167/500, Train metric: 1.4851
# Estimator 168/500, Train metric: 1.4802
# Estimator 169/500, Train metric: 1.4784
# Estimator 170/500, Train metric: 1.4728
# Estimator 171/500, Train metric: 1.4657
# Estimator 172/500, Train metric: 1.4567
# Estimator 173/500, Train metric: 1.4473
# Estimator 174/500, Train metric: 1.4410
# Estimator 175/500, Train metric: 1.4304
# Estimator 176/500, Train metric: 1.4238
# Estimator 177/500, Train metric: 1.4139
# Estimator 178/500, Train metric: 1.4082
# Estimator 179/500, Train metric: 1.4044
# Estimator 180/500, Train metric: 1.4045
# Estimator 181/500, Train metric: 1.3974
# Estimator 182/500, Train metric: 1.3909
# Estimator 183/500, Train metric: 1.3893
# Estimator 184/500, Train metric: 1.3872
# Estimator 185/500, Train metric: 1.3842
# Estimator 186/500, Train metric: 1.3773
# Estimator 187/500, Train metric: 1.3731
# Estimator 188/500, Train metric: 1.3707
# Estimator 189/500, Train metric: 1.3634
# Estimator 190/500, Train metric: 1.3570
# Estimator 191/500, Train metric: 1.3517
# Estimator 192/500, Train metric: 1.3488
# Estimator 193/500, Train metric: 1.3457
# Estimator 194/500, Train metric: 1.3375
# Estimator 195/500, Train metric: 1.3337
# Estimator 196/500, Train metric: 1.3284
# Estimator 197/500, Train metric: 1.3278
# Estimator 198/500, Train metric: 1.3216
# Estimator 199/500, Train metric: 1.3152
# Estimator 200/500, Train metric: 1.3136
# Estimator 201/500, Train metric: 1.3056
# Estimator 202/500, Train metric: 1.3027
# Estimator 203/500, Train metric: 1.3000
# Estimator 204/500, Train metric: 1.2962
# Estimator 205/500, Train metric: 1.2887
# Estimator 206/500, Train metric: 1.2836
# Estimator 207/500, Train metric: 1.2799
# Estimator 208/500, Train metric: 1.2711
# Estimator 209/500, Train metric: 1.2687
# Estimator 210/500, Train metric: 1.2657
# Estimator 211/500, Train metric: 1.2585
# Estimator 212/500, Train metric: 1.2566
# Estimator 213/500, Train metric: 1.2519
# Estimator 214/500, Train metric: 1.2487
# Estimator 215/500, Train metric: 1.2479
# Estimator 216/500, Train metric: 1.2434
# Estimator 217/500, Train metric: 1.2388
# Estimator 218/500, Train metric: 1.2332
# Estimator 219/500, Train metric: 1.2301
# Estimator 220/500, Train metric: 1.2272
# Estimator 221/500, Train metric: 1.2255
# Estimator 222/500, Train metric: 1.2255
# Estimator 223/500, Train metric: 1.2249
# Estimator 224/500, Train metric: 1.2219
# Estimator 225/500, Train metric: 1.2179
# Estimator 226/500, Train metric: 1.2134
# Estimator 227/500, Train metric: 1.2128
# Estimator 228/500, Train metric: 1.2095
# Estimator 229/500, Train metric: 1.2085
# Estimator 230/500, Train metric: 1.2080
# Estimator 231/500, Train metric: 1.2062
# Estimator 232/500, Train metric: 1.2053
# Estimator 233/500, Train metric: 1.2017
# Estimator 234/500, Train metric: 1.1998
# Estimator 235/500, Train metric: 1.1972
# Estimator 236/500, Train metric: 1.1943
# Estimator 237/500, Train metric: 1.1916
# Estimator 238/500, Train metric: 1.1901
# Estimator 239/500, Train metric: 1.1870
# Estimator 240/500, Train metric: 1.1856
# Estimator 241/500, Train metric: 1.1820
# Estimator 242/500, Train metric: 1.1808
# Estimator 243/500, Train metric: 1.1764
# Estimator 244/500, Train metric: 1.1727
# Estimator 245/500, Train metric: 1.1690
# Estimator 246/500, Train metric: 1.1674
# Estimator 247/500, Train metric: 1.1621
# Estimator 248/500, Train metric: 1.1591
# Estimator 249/500, Train metric: 1.1531
# Estimator 250/500, Train metric: 1.1505
# Estimator 251/500, Train metric: 1.1480
# Estimator 252/500, Train metric: 1.1477
# Estimator 253/500, Train metric: 1.1477
# Estimator 254/500, Train metric: 1.1474
# Estimator 255/500, Train metric: 1.1487
# Estimator 256/500, Train metric: 1.1445
# Estimator 257/500, Train metric: 1.1443
# Estimator 258/500, Train metric: 1.1392
# Estimator 259/500, Train metric: 1.1361
# Estimator 260/500, Train metric: 1.1340
# Estimator 261/500, Train metric: 1.1318
# Estimator 262/500, Train metric: 1.1298
# Estimator 263/500, Train metric: 1.1300
# Estimator 264/500, Train metric: 1.1296
# Estimator 265/500, Train metric: 1.1272
# Estimator 266/500, Train metric: 1.1227
# Estimator 267/500, Train metric: 1.1224
# Estimator 268/500, Train metric: 1.1216
# Estimator 269/500, Train metric: 1.1207
# Estimator 270/500, Train metric: 1.1197
# Estimator 271/500, Train metric: 1.1168
# Estimator 272/500, Train metric: 1.1122
# Estimator 273/500, Train metric: 1.1089
# Estimator 274/500, Train metric: 1.1061
# Estimator 275/500, Train metric: 1.1068
# Estimator 276/500, Train metric: 1.1049
# Estimator 277/500, Train metric: 1.1048
# Estimator 278/500, Train metric: 1.1010
# Estimator 279/500, Train metric: 1.0975
# Estimator 280/500, Train metric: 1.0944
# Estimator 281/500, Train metric: 1.0938
# Estimator 282/500, Train metric: 1.0925
# Estimator 283/500, Train metric: 1.0895
# Estimator 284/500, Train metric: 1.0893
# Estimator 285/500, Train metric: 1.0895
# Estimator 286/500, Train metric: 1.0868
# Estimator 287/500, Train metric: 1.0849
# Estimator 288/500, Train metric: 1.0839
# Estimator 289/500, Train metric: 1.0839
# Estimator 290/500, Train metric: 1.0822
# Estimator 291/500, Train metric: 1.0807
# Estimator 292/500, Train metric: 1.0759
# Estimator 293/500, Train metric: 1.0760
# Estimator 294/500, Train metric: 1.0745
# Estimator 295/500, Train metric: 1.0749
# Estimator 296/500, Train metric: 1.0745
# Estimator 297/500, Train metric: 1.0743
# Estimator 298/500, Train metric: 1.0737
# Estimator 299/500, Train metric: 1.0738
# Estimator 300/500, Train metric: 1.0732
# Estimator 301/500, Train metric: 1.0704
# Estimator 302/500, Train metric: 1.0682
# Estimator 303/500, Train metric: 1.0650
# Estimator 304/500, Train metric: 1.0635
# Estimator 305/500, Train metric: 1.0608
# Estimator 306/500, Train metric: 1.0602
# Estimator 307/500, Train metric: 1.0583
# Estimator 308/500, Train metric: 1.0556
# Estimator 309/500, Train metric: 1.0540
# Estimator 310/500, Train metric: 1.0527
# Estimator 311/500, Train metric: 1.0527
# Estimator 312/500, Train metric: 1.0501
# Estimator 313/500, Train metric: 1.0482
# Estimator 314/500, Train metric: 1.0467
# Estimator 315/500, Train metric: 1.0426
# Estimator 316/500, Train metric: 1.0425
# Estimator 317/500, Train metric: 1.0408
# Estimator 318/500, Train metric: 1.0392
# Estimator 319/500, Train metric: 1.0382
# Estimator 320/500, Train metric: 1.0372
# Estimator 321/500, Train metric: 1.0353
# Estimator 322/500, Train metric: 1.0325
# Estimator 323/500, Train metric: 1.0308
# Estimator 324/500, Train metric: 1.0262
# Estimator 325/500, Train metric: 1.0237
# Estimator 326/500, Train metric: 1.0218
# Estimator 327/500, Train metric: 1.0197
# Estimator 328/500, Train metric: 1.0161
# Estimator 329/500, Train metric: 1.0156
# Estimator 330/500, Train metric: 1.0149
# Estimator 331/500, Train metric: 1.0147
# Estimator 332/500, Train metric: 1.0129
# Estimator 333/500, Train metric: 1.0123
# Estimator 334/500, Train metric: 1.0111
# Estimator 335/500, Train metric: 1.0105
# Estimator 336/500, Train metric: 1.0114
# Estimator 337/500, Train metric: 1.0105
# Estimator 338/500, Train metric: 1.0100
# Estimator 339/500, Train metric: 1.0092
# Estimator 340/500, Train metric: 1.0090
# Estimator 341/500, Train metric: 1.0066
# Estimator 342/500, Train metric: 1.0065
# Estimator 343/500, Train metric: 1.0068
# Estimator 344/500, Train metric: 1.0066
# Estimator 345/500, Train metric: 1.0050
# Estimator 346/500, Train metric: 1.0033
# Estimator 347/500, Train metric: 1.0013
# Estimator 348/500, Train metric: 1.0005
# Estimator 349/500, Train metric: 0.9979
# Estimator 350/500, Train metric: 0.9973
# Estimator 351/500, Train metric: 0.9971
# Estimator 352/500, Train metric: 0.9971
# Estimator 353/500, Train metric: 0.9971
# Estimator 354/500, Train metric: 0.9964
# Estimator 355/500, Train metric: 0.9929
# Estimator 356/500, Train metric: 0.9922
# Estimator 357/500, Train metric: 0.9919
# Estimator 358/500, Train metric: 0.9940
# Estimator 359/500, Train metric: 0.9934
# Estimator 360/500, Train metric: 0.9913
# Estimator 361/500, Train metric: 0.9878
# Estimator 362/500, Train metric: 0.9878
# Estimator 363/500, Train metric: 0.9851
# Estimator 364/500, Train metric: 0.9827
# Estimator 365/500, Train metric: 0.9800
# Estimator 366/500, Train metric: 0.9796
# Estimator 367/500, Train metric: 0.9785
# Estimator 368/500, Train metric: 0.9761
# Estimator 369/500, Train metric: 0.9759
# Estimator 370/500, Train metric: 0.9751
# Estimator 371/500, Train metric: 0.9757
# Estimator 372/500, Train metric: 0.9746
# Estimator 373/500, Train metric: 0.9743
# Estimator 374/500, Train metric: 0.9729
# Estimator 375/500, Train metric: 0.9731
# Estimator 376/500, Train metric: 0.9738
# Estimator 377/500, Train metric: 0.9743
# Estimator 378/500, Train metric: 0.9744
# Estimator 379/500, Train metric: 0.9733
# Estimator 380/500, Train metric: 0.9722
# Estimator 381/500, Train metric: 0.9709
# Estimator 382/500, Train metric: 0.9708
# Estimator 383/500, Train metric: 0.9700
# Estimator 384/500, Train metric: 0.9705
# Estimator 385/500, Train metric: 0.9691
# Estimator 386/500, Train metric: 0.9684
# Estimator 387/500, Train metric: 0.9670
# Estimator 388/500, Train metric: 0.9658
# Estimator 389/500, Train metric: 0.9647
# Estimator 390/500, Train metric: 0.9638
# Estimator 391/500, Train metric: 0.9632
# Estimator 392/500, Train metric: 0.9605
# Estimator 393/500, Train metric: 0.9600
# Estimator 394/500, Train metric: 0.9596
# Estimator 395/500, Train metric: 0.9584
# Estimator 396/500, Train metric: 0.9581
# Estimator 397/500, Train metric: 0.9577
# Estimator 398/500, Train metric: 0.9570
# Estimator 399/500, Train metric: 0.9563
# Estimator 400/500, Train metric: 0.9557
# Estimator 401/500, Train metric: 0.9554
# Estimator 402/500, Train metric: 0.9547
# Estimator 403/500, Train metric: 0.9530
# Estimator 404/500, Train metric: 0.9530
# Estimator 405/500, Train metric: 0.9484
# Estimator 406/500, Train metric: 0.9490
# Estimator 407/500, Train metric: 0.9482
# Estimator 408/500, Train metric: 0.9476
# Estimator 409/500, Train metric: 0.9476
# Estimator 410/500, Train metric: 0.9476
# Estimator 411/500, Train metric: 0.9476
# Estimator 412/500, Train metric: 0.9471
# Estimator 413/500, Train metric: 0.9463
# Estimator 414/500, Train metric: 0.9460
# Estimator 415/500, Train metric: 0.9444
# Estimator 416/500, Train metric: 0.9444
# Estimator 417/500, Train metric: 0.9436
# Estimator 418/500, Train metric: 0.9425
# Estimator 419/500, Train metric: 0.9421
# Estimator 420/500, Train metric: 0.9420
# Estimator 421/500, Train metric: 0.9421
# Estimator 422/500, Train metric: 0.9408
# Estimator 423/500, Train metric: 0.9396
# Estimator 424/500, Train metric: 0.9396
# Estimator 425/500, Train metric: 0.9386
# Estimator 426/500, Train metric: 0.9387
# Estimator 427/500, Train metric: 0.9373
# Estimator 428/500, Train metric: 0.9368
# Estimator 429/500, Train metric: 0.9367
# Estimator 430/500, Train metric: 0.9365
# Estimator 431/500, Train metric: 0.9368
# Estimator 432/500, Train metric: 0.9362
# Estimator 433/500, Train metric: 0.9359
# Estimator 434/500, Train metric: 0.9356
# Estimator 435/500, Train metric: 0.9338
# Estimator 436/500, Train metric: 0.9333
# Estimator 437/500, Train metric: 0.9334
# Estimator 438/500, Train metric: 0.9308
# Estimator 439/500, Train metric: 0.9308
# Estimator 440/500, Train metric: 0.9295
# Estimator 441/500, Train metric: 0.9266
# Estimator 442/500, Train metric: 0.9264
# Estimator 443/500, Train metric: 0.9266
# Estimator 444/500, Train metric: 0.9265
# Estimator 445/500, Train metric: 0.9270
# Estimator 446/500, Train metric: 0.9269
# Estimator 447/500, Train metric: 0.9251
# Estimator 448/500, Train metric: 0.9246
# Estimator 449/500, Train metric: 0.9247
# Estimator 450/500, Train metric: 0.9232
# Estimator 451/500, Train metric: 0.9234
# Estimator 452/500, Train metric: 0.9235
# Estimator 453/500, Train metric: 0.9236
# Estimator 454/500, Train metric: 0.9217
# Estimator 455/500, Train metric: 0.9209
# Estimator 456/500, Train metric: 0.9210
# Estimator 457/500, Train metric: 0.9209
# Estimator 458/500, Train metric: 0.9201
# Estimator 459/500, Train metric: 0.9199
# Estimator 460/500, Train metric: 0.9192
# Estimator 461/500, Train metric: 0.9188
# Estimator 462/500, Train metric: 0.9188
# Estimator 463/500, Train metric: 0.9188
# Estimator 464/500, Train metric: 0.9189
# Estimator 465/500, Train metric: 0.9191
# Estimator 466/500, Train metric: 0.9192
# Estimator 467/500, Train metric: 0.9180
# Estimator 468/500, Train metric: 0.9181
# Estimator 469/500, Train metric: 0.9168
# Estimator 470/500, Train metric: 0.9171
# Estimator 471/500, Train metric: 0.9164
# Estimator 472/500, Train metric: 0.9164
# Estimator 473/500, Train metric: 0.9164
# Estimator 474/500, Train metric: 0.9163
# Estimator 475/500, Train metric: 0.9136
# Estimator 476/500, Train metric: 0.9135
# Estimator 477/500, Train metric: 0.9124
# Estimator 478/500, Train metric: 0.9119
# Estimator 479/500, Train metric: 0.9117
# Estimator 480/500, Train metric: 0.9115
# Estimator 481/500, Train metric: 0.9111
# Estimator 482/500, Train metric: 0.9111
# Estimator 483/500, Train metric: 0.9078
# Estimator 484/500, Train metric: 0.9076
# Estimator 485/500, Train metric: 0.9065
# Estimator 486/500, Train metric: 0.9060
# Estimator 487/500, Train metric: 0.9058
# Estimator 488/500, Train metric: 0.9057
# Estimator 489/500, Train metric: 0.9059
# Estimator 490/500, Train metric: 0.9033
# Estimator 491/500, Train metric: 0.9029
# Estimator 492/500, Train metric: 0.9024
# Estimator 493/500, Train metric: 0.9025
# Estimator 494/500, Train metric: 0.9022
# Estimator 495/500, Train metric: 0.9022
# Estimator 496/500, Train metric: 0.9020
# Estimator 497/500, Train metric: 0.9016
# Estimator 498/500, Train metric: 0.9016
# Estimator 499/500, Train metric: 0.9001
# Best MSE for PGBM with WilcoxonPruner: 7.2205585617731005 with params: {'min_split_gain': 0.7501302539884351, 'learning_rate': 0.14607345891678616, 'reg_lambda': 9.999999999999998, 'max_leaves': 45, 'n_estimators': 500, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'tree_correlation': 0.27719006397085505}
# Best RMSE for PGBM with WilcoxonPruner: 2.6871097040822693
# Correlation Coefficient for PGBM with WilcoxonPruner: 0.9633681999745222
#
# Best model on test data: LightGBM with PercentilePruner
# Test MSE: 6.2444486776418495
# Test RMSE: 2.498889488881381
# Correlation Coefficient: 0.9681860307455313
# Best Parameters: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 400, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'verbose': -1}
# Pruner Used: PercentilePruner

# %% [markdown]
# # **Probabilistic distributions using NGBoost**

# %%
# Assuming best_params is obtained correctly
best_params = get_best_model_params(best_scores_autosampler, 'NGBoost')

# Remove any conflicting parameters from best_params
incompatible_keys = ['Dist', 'Score']
for key in incompatible_keys:
    best_params.pop(key, None)

# Initialize NGBoost model with best_params
ngb_model = NGBRegressor(Dist=Normal, **best_params)

# Fit the model
ngb_model.fit(X_train, y_train)

# Predict the distribution
pred_dist = ngb_model.pred_dist(X_test)

# Extract mean and standard deviation
predictions_NGB_df = pd.DataFrame({
    'Mean': pred_dist.loc,
    'StdDev': pred_dist.scale,
    'Actual': y_test.ravel()
})

# Calculate and print the mean squared error
mse = mean_squared_error(y_test, pred_dist.loc)
print(f"Mean Squared Error: {mse:.2f}")

# Print the DataFrame with mean and standard deviation
print(predictions_NGB_df.head())
# Out:
# Mean Squared Error: 7.45
#         Mean    StdDev  Actual
# 0  33.373885  0.430658    34.0
# 1  35.378945  0.288751    36.0
# 2  34.324591  0.598455    36.0
# 3  35.418704  0.504567    35.0
# 4  46.612293  0.067936    44.6

# %%
excel_path = "./drive/MyDrive/Concrete_ml/NGBoost_Prob.xlsx"

# Plot the standard deviation of the predictions
plt.figure(figsize=(12, 6))
plt.plot(
    predictions_NGB_df['StdDev'],
    label='Standard Deviation',
    color='green',
    marker='o',
    linestyle='dashed'
)
plt.xlabel('Sample Index')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation of NGBoost Predictions')
plt.legend()
plt.grid(True)

# Save the standard deviation plot
stddev_plot_path = 'stddev_plot.png'
plt.savefig(stddev_plot_path)
plt.close()

# Plot the actual vs predicted mean with confidence intervals
plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(
    y_test,
    label='Actual',
    color='black',
    marker='o',
    linestyle='dashed',
    linewidth=1,
    markersize=4
)

# Plot predicted mean
plt.plot(
    predictions_NGB_df['Mean'],
    label='Predicted Mean',
    color='red',
    marker='x',
    linestyle='dashed',
    linewidth=1,
    markersize=4
)

# Calculate and plot confidence intervals
confidence_interval = 1.96 * predictions_NGB_df['StdDev']  # 95% confidence interval
plt.fill_between(
    np.arange(len(predictions_NGB_df)),
    predictions_NGB_df['Mean'] - confidence_interval,
    predictions_NGB_df['Mean'] + confidence_interval,
    color='blue',
    alpha=0.2,
    label='95% Confidence Interval'
)
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('NGBoost Predictions with Confidence Intervals')
plt.legend()
plt.grid(True)

# Save the prediction plot
prediction_plot_path = 'prediction_plot.png'
plt.savefig(prediction_plot_path)
plt.close()

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(excel_path, engine='xlsxwriter')

# Write the dataframe to a worksheet.
predictions_NGB_df.to_excel(writer, sheet_name='Predictions', index=False)

# Access the XlsxWriter workbook and worksheet objects from the writer object.
workbook = writer.book
worksheet = writer.sheets['Predictions']

# Insert the standard deviation plot into a new worksheet.
worksheet_stddev = workbook.add_worksheet('StdDev Plot')
worksheet_stddev.insert_image('A1', stddev_plot_path)

# Insert the prediction plot into a new worksheet.
worksheet_prediction = workbook.add_worksheet('Predictions Plot')
worksheet_prediction.insert_image('A1', prediction_plot_path)

# Close the Pandas Excel writer and output the Excel file.
writer.close()
print(f"Excel file saved at {excel_path}")

# Optionally, remove the image files now that they're embedded in the Excel file
os.remove(stddev_plot_path)
os.remove(prediction_plot_path)
# Out:
# Excel file saved at ./drive/MyDrive/Concrete_ml/NGBoost_Prob.xlsx

# %% [markdown]
# # **Probabilistic distributions using PGBM**

# %%
# Assuming best_params is obtained correctly
best_params = get_best_model_params(best_scores_autosampler, 'PGBM')

# Remove any conflicting parameters from best_params
# Note: Adjust the incompatible keys based on PGBM's requirements
incompatible_keys = ['Dist', 'Score']
for key in incompatible_keys:
    best_params.pop(key, None)

# Initialize PGBM model
pgbm_model = PGBM()

def mseloss_objective(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    # Ensure that yhat and y are PyTorch tensors
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
# Fit the model
pgbm_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params = best_params)

# Predict the distribution
pred_dist = pgbm_model.predict_dist(X_test)

# Extract mean and standard deviation
# Note: PGBM might return predictions in a different format, adjust accordingly
predictions_PGBM_df = pd.DataFrame({
    'Mean': pred_dist.mean(axis=0),
    'StdDev': pred_dist.std(axis=0),
    'Actual': y_test.ravel()
})

# Calculate and print the mean squared error
mse = mean_squared_error(y_test, predictions_PGBM_df['Mean'])
print(f"Mean Squared Error: {mse:.2f}")

# Print the DataFrame with mean and standard deviation
print(predictions_PGBM_df.head())
# Out:
# Training on CPU
# Estimator 0/418, Train metric: 9.3999
# Estimator 1/418, Train metric: 8.8771
# Estimator 2/418, Train metric: 8.5316
# Estimator 3/418, Train metric: 8.1580
# Estimator 4/418, Train metric: 7.9409
# Estimator 5/418, Train metric: 7.6378
# Estimator 6/418, Train metric: 7.3519
# Estimator 7/418, Train metric: 6.9604
# Estimator 8/418, Train metric: 6.6809
# Estimator 9/418, Train metric: 6.5109
# Estimator 10/418, Train metric: 6.2874
# Estimator 11/418, Train metric: 6.0333
# Estimator 12/418, Train metric: 5.7893
# Estimator 13/418, Train metric: 5.6506
# Estimator 14/418, Train metric: 5.4705
# Estimator 15/418, Train metric: 5.2711
# Estimator 16/418, Train metric: 5.0986
# Estimator 17/418, Train metric: 4.9619
# Estimator 18/418, Train metric: 4.8398
# Estimator 19/418, Train metric: 4.7303
# Estimator 20/418, Train metric: 4.6153
# Estimator 21/418, Train metric: 4.5145
# Estimator 22/418, Train metric: 4.3984
# Estimator 23/418, Train metric: 4.2655
# Estimator 24/418, Train metric: 4.1554
# Estimator 25/418, Train metric: 4.0742
# Estimator 26/418, Train metric: 3.9835
# Estimator 27/418, Train metric: 3.9004
# Estimator 28/418, Train metric: 3.8212
# Estimator 29/418, Train metric: 3.7437
# Estimator 30/418, Train metric: 3.6856
# Estimator 31/418, Train metric: 3.5846
# Estimator 32/418, Train metric: 3.5276
# Estimator 33/418, Train metric: 3.4599
# Estimator 34/418, Train metric: 3.4044
# Estimator 35/418, Train metric: 3.3595
# Estimator 36/418, Train metric: 3.2884
# Estimator 37/418, Train metric: 3.2258
# Estimator 38/418, Train metric: 3.1825
# Estimator 39/418, Train metric: 3.1392
# Estimator 40/418, Train metric: 3.0889
# Estimator 41/418, Train metric: 3.0282
# Estimator 42/418, Train metric: 2.9828
# Estimator 43/418, Train metric: 2.9318
# Estimator 44/418, Train metric: 2.8946
# Estimator 45/418, Train metric: 2.8577
# Estimator 46/418, Train metric: 2.8238
# Estimator 47/418, Train metric: 2.7840
# Estimator 48/418, Train metric: 2.7386
# Estimator 49/418, Train metric: 2.7190
# Estimator 50/418, Train metric: 2.6806
# Estimator 51/418, Train metric: 2.6510
# Estimator 52/418, Train metric: 2.6171
# Estimator 53/418, Train metric: 2.5875
# Estimator 54/418, Train metric: 2.5398
# Estimator 55/418, Train metric: 2.4988
# Estimator 56/418, Train metric: 2.4714
# Estimator 57/418, Train metric: 2.4422
# Estimator 58/418, Train metric: 2.4061
# Estimator 59/418, Train metric: 2.3780
# Estimator 60/418, Train metric: 2.3486
# Estimator 61/418, Train metric: 2.3240
# Estimator 62/418, Train metric: 2.2961
# Estimator 63/418, Train metric: 2.2666
# Estimator 64/418, Train metric: 2.2482
# Estimator 65/418, Train metric: 2.2273
# Estimator 66/418, Train metric: 2.2003
# Estimator 67/418, Train metric: 2.1808
# Estimator 68/418, Train metric: 2.1572
# Estimator 69/418, Train metric: 2.1281
# Estimator 70/418, Train metric: 2.1131
# Estimator 71/418, Train metric: 2.0880
# Estimator 72/418, Train metric: 2.0619
# Estimator 73/418, Train metric: 2.0407
# Estimator 74/418, Train metric: 2.0183
# Estimator 75/418, Train metric: 1.9969
# Estimator 76/418, Train metric: 1.9770
# Estimator 77/418, Train metric: 1.9636
# Estimator 78/418, Train metric: 1.9325
# Estimator 79/418, Train metric: 1.9136
# Estimator 80/418, Train metric: 1.8885
# Estimator 81/418, Train metric: 1.8638
# Estimator 82/418, Train metric: 1.8503
# Estimator 83/418, Train metric: 1.8362
# Estimator 84/418, Train metric: 1.8232
# Estimator 85/418, Train metric: 1.8074
# Estimator 86/418, Train metric: 1.7913
# Estimator 87/418, Train metric: 1.7798
# Estimator 88/418, Train metric: 1.7704
# Estimator 89/418, Train metric: 1.7518
# Estimator 90/418, Train metric: 1.7372
# Estimator 91/418, Train metric: 1.7254
# Estimator 92/418, Train metric: 1.7133
# Estimator 93/418, Train metric: 1.6957
# Estimator 94/418, Train metric: 1.6872
# Estimator 95/418, Train metric: 1.6762
# Estimator 96/418, Train metric: 1.6640
# Estimator 97/418, Train metric: 1.6477
# Estimator 98/418, Train metric: 1.6299
# Estimator 99/418, Train metric: 1.6176
# Estimator 100/418, Train metric: 1.6018
# Estimator 101/418, Train metric: 1.5899
# Estimator 102/418, Train metric: 1.5764
# Estimator 103/418, Train metric: 1.5625
# Estimator 104/418, Train metric: 1.5535
# Estimator 105/418, Train metric: 1.5457
# Estimator 106/418, Train metric: 1.5320
# Estimator 107/418, Train metric: 1.5182
# Estimator 108/418, Train metric: 1.5033
# Estimator 109/418, Train metric: 1.4921
# Estimator 110/418, Train metric: 1.4833
# Estimator 111/418, Train metric: 1.4692
# Estimator 112/418, Train metric: 1.4617
# Estimator 113/418, Train metric: 1.4491
# Estimator 114/418, Train metric: 1.4377
# Estimator 115/418, Train metric: 1.4232
# Estimator 116/418, Train metric: 1.4133
# Estimator 117/418, Train metric: 1.4029
# Estimator 118/418, Train metric: 1.3969
# Estimator 119/418, Train metric: 1.3850
# Estimator 120/418, Train metric: 1.3763
# Estimator 121/418, Train metric: 1.3676
# Estimator 122/418, Train metric: 1.3561
# Estimator 123/418, Train metric: 1.3479
# Estimator 124/418, Train metric: 1.3404
# Estimator 125/418, Train metric: 1.3335
# Estimator 126/418, Train metric: 1.3242
# Estimator 127/418, Train metric: 1.3157
# Estimator 128/418, Train metric: 1.3114
# Estimator 129/418, Train metric: 1.3034
# Estimator 130/418, Train metric: 1.2985
# Estimator 131/418, Train metric: 1.2945
# Estimator 132/418, Train metric: 1.2858
# Estimator 133/418, Train metric: 1.2783
# Estimator 134/418, Train metric: 1.2670
# Estimator 135/418, Train metric: 1.2601
# Estimator 136/418, Train metric: 1.2544
# Estimator 137/418, Train metric: 1.2474
# Estimator 138/418, Train metric: 1.2416
# Estimator 139/418, Train metric: 1.2345
# Estimator 140/418, Train metric: 1.2244
# Estimator 141/418, Train metric: 1.2209
# Estimator 142/418, Train metric: 1.2192
# Estimator 143/418, Train metric: 1.2151
# Estimator 144/418, Train metric: 1.2068
# Estimator 145/418, Train metric: 1.2026
# Estimator 146/418, Train metric: 1.1957
# Estimator 147/418, Train metric: 1.1897
# Estimator 148/418, Train metric: 1.1858
# Estimator 149/418, Train metric: 1.1784
# Estimator 150/418, Train metric: 1.1690
# Estimator 151/418, Train metric: 1.1605
# Estimator 152/418, Train metric: 1.1563
# Estimator 153/418, Train metric: 1.1526
# Estimator 154/418, Train metric: 1.1495
# Estimator 155/418, Train metric: 1.1434
# Estimator 156/418, Train metric: 1.1377
# Estimator 157/418, Train metric: 1.1333
# Estimator 158/418, Train metric: 1.1259
# Estimator 159/418, Train metric: 1.1203
# Estimator 160/418, Train metric: 1.1126
# Estimator 161/418, Train metric: 1.1093
# Estimator 162/418, Train metric: 1.1046
# Estimator 163/418, Train metric: 1.1002
# Estimator 164/418, Train metric: 1.0964
# Estimator 165/418, Train metric: 1.0887
# Estimator 166/418, Train metric: 1.0823
# Estimator 167/418, Train metric: 1.0791
# Estimator 168/418, Train metric: 1.0746
# Estimator 169/418, Train metric: 1.0708
# Estimator 170/418, Train metric: 1.0683
# Estimator 171/418, Train metric: 1.0631
# Estimator 172/418, Train metric: 1.0615
# Estimator 173/418, Train metric: 1.0568
# Estimator 174/418, Train metric: 1.0515
# Estimator 175/418, Train metric: 1.0453
# Estimator 176/418, Train metric: 1.0405
# Estimator 177/418, Train metric: 1.0361
# Estimator 178/418, Train metric: 1.0313
# Estimator 179/418, Train metric: 1.0287
# Estimator 180/418, Train metric: 1.0268
# Estimator 181/418, Train metric: 1.0212
# Estimator 182/418, Train metric: 1.0196
# Estimator 183/418, Train metric: 1.0147
# Estimator 184/418, Train metric: 1.0105
# Estimator 185/418, Train metric: 1.0086
# Estimator 186/418, Train metric: 1.0040
# Estimator 187/418, Train metric: 1.0001
# Estimator 188/418, Train metric: 0.9980
# Estimator 189/418, Train metric: 0.9920
# Estimator 190/418, Train metric: 0.9879
# Estimator 191/418, Train metric: 0.9838
# Estimator 192/418, Train metric: 0.9791
# Estimator 193/418, Train metric: 0.9756
# Estimator 194/418, Train metric: 0.9742
# Estimator 195/418, Train metric: 0.9710
# Estimator 196/418, Train metric: 0.9688
# Estimator 197/418, Train metric: 0.9643
# Estimator 198/418, Train metric: 0.9599
# Estimator 199/418, Train metric: 0.9555
# Estimator 200/418, Train metric: 0.9529
# Estimator 201/418, Train metric: 0.9495
# Estimator 202/418, Train metric: 0.9473
# Estimator 203/418, Train metric: 0.9444
# Estimator 204/418, Train metric: 0.9423
# Estimator 205/418, Train metric: 0.9386
# Estimator 206/418, Train metric: 0.9356
# Estimator 207/418, Train metric: 0.9325
# Estimator 208/418, Train metric: 0.9301
# Estimator 209/418, Train metric: 0.9292
# Estimator 210/418, Train metric: 0.9269
# Estimator 211/418, Train metric: 0.9235
# Estimator 212/418, Train metric: 0.9213
# Estimator 213/418, Train metric: 0.9185
# Estimator 214/418, Train metric: 0.9166
# Estimator 215/418, Train metric: 0.9128
# Estimator 216/418, Train metric: 0.9107
# Estimator 217/418, Train metric: 0.9080
# Estimator 218/418, Train metric: 0.9041
# Estimator 219/418, Train metric: 0.9006
# Estimator 220/418, Train metric: 0.8974
# Estimator 221/418, Train metric: 0.8963
# Estimator 222/418, Train metric: 0.8953
# Estimator 223/418, Train metric: 0.8927
# Estimator 224/418, Train metric: 0.8909
# Estimator 225/418, Train metric: 0.8871
# Estimator 226/418, Train metric: 0.8841
# Estimator 227/418, Train metric: 0.8817
# Estimator 228/418, Train metric: 0.8795
# Estimator 229/418, Train metric: 0.8788
# Estimator 230/418, Train metric: 0.8764
# Estimator 231/418, Train metric: 0.8747
# Estimator 232/418, Train metric: 0.8724
# Estimator 233/418, Train metric: 0.8703
# Estimator 234/418, Train metric: 0.8666
# Estimator 235/418, Train metric: 0.8641
# Estimator 236/418, Train metric: 0.8603
# Estimator 237/418, Train metric: 0.8578
# Estimator 238/418, Train metric: 0.8562
# Estimator 239/418, Train metric: 0.8532
# Estimator 240/418, Train metric: 0.8513
# Estimator 241/418, Train metric: 0.8496
# Estimator 242/418, Train metric: 0.8477
# Estimator 243/418, Train metric: 0.8450
# Estimator 244/418, Train metric: 0.8414
# Estimator 245/418, Train metric: 0.8394
# Estimator 246/418, Train metric: 0.8380
# Estimator 247/418, Train metric: 0.8361
# Estimator 248/418, Train metric: 0.8350
# Estimator 249/418, Train metric: 0.8324
# Estimator 250/418, Train metric: 0.8310
# Estimator 251/418, Train metric: 0.8285
# Estimator 252/418, Train metric: 0.8256
# Estimator 253/418, Train metric: 0.8240
# Estimator 254/418, Train metric: 0.8215
# Estimator 255/418, Train metric: 0.8203
# Estimator 256/418, Train metric: 0.8179
# Estimator 257/418, Train metric: 0.8160
# Estimator 258/418, Train metric: 0.8133
# Estimator 259/418, Train metric: 0.8112
# Estimator 260/418, Train metric: 0.8103
# Estimator 261/418, Train metric: 0.8070
# Estimator 262/418, Train metric: 0.8037
# Estimator 263/418, Train metric: 0.8027
# Estimator 264/418, Train metric: 0.8012
# Estimator 265/418, Train metric: 0.7988
# Estimator 266/418, Train metric: 0.7973
# Estimator 267/418, Train metric: 0.7956
# Estimator 268/418, Train metric: 0.7948
# Estimator 269/418, Train metric: 0.7937
# Estimator 270/418, Train metric: 0.7918
# Estimator 271/418, Train metric: 0.7900
# Estimator 272/418, Train metric: 0.7870
# Estimator 273/418, Train metric: 0.7855
# Estimator 274/418, Train metric: 0.7831
# Estimator 275/418, Train metric: 0.7815
# Estimator 276/418, Train metric: 0.7799
# Estimator 277/418, Train metric: 0.7787
# Estimator 278/418, Train metric: 0.7777
# Estimator 279/418, Train metric: 0.7762
# Estimator 280/418, Train metric: 0.7750
# Estimator 281/418, Train metric: 0.7739
# Estimator 282/418, Train metric: 0.7723
# Estimator 283/418, Train metric: 0.7712
# Estimator 284/418, Train metric: 0.7706
# Estimator 285/418, Train metric: 0.7694
# Estimator 286/418, Train metric: 0.7677
# Estimator 287/418, Train metric: 0.7664
# Estimator 288/418, Train metric: 0.7655
# Estimator 289/418, Train metric: 0.7639
# Estimator 290/418, Train metric: 0.7620
# Estimator 291/418, Train metric: 0.7601
# Estimator 292/418, Train metric: 0.7589
# Estimator 293/418, Train metric: 0.7581
# Estimator 294/418, Train metric: 0.7568
# Estimator 295/418, Train metric: 0.7554
# Estimator 296/418, Train metric: 0.7544
# Estimator 297/418, Train metric: 0.7531
# Estimator 298/418, Train metric: 0.7512
# Estimator 299/418, Train metric: 0.7499
# Estimator 300/418, Train metric: 0.7478
# Estimator 301/418, Train metric: 0.7460
# Estimator 302/418, Train metric: 0.7449
# Estimator 303/418, Train metric: 0.7428
# Estimator 304/418, Train metric: 0.7419
# Estimator 305/418, Train metric: 0.7408
# Estimator 306/418, Train metric: 0.7394
# Estimator 307/418, Train metric: 0.7383
# Estimator 308/418, Train metric: 0.7363
# Estimator 309/418, Train metric: 0.7336
# Estimator 310/418, Train metric: 0.7317
# Estimator 311/418, Train metric: 0.7310
# Estimator 312/418, Train metric: 0.7291
# Estimator 313/418, Train metric: 0.7269
# Estimator 314/418, Train metric: 0.7259
# Estimator 315/418, Train metric: 0.7238
# Estimator 316/418, Train metric: 0.7225
# Estimator 317/418, Train metric: 0.7213
# Estimator 318/418, Train metric: 0.7192
# Estimator 319/418, Train metric: 0.7184
# Estimator 320/418, Train metric: 0.7172
# Estimator 321/418, Train metric: 0.7165
# Estimator 322/418, Train metric: 0.7153
# Estimator 323/418, Train metric: 0.7142
# Estimator 324/418, Train metric: 0.7129
# Estimator 325/418, Train metric: 0.7117
# Estimator 326/418, Train metric: 0.7097
# Estimator 327/418, Train metric: 0.7081
# Estimator 328/418, Train metric: 0.7070
# Estimator 329/418, Train metric: 0.7061
# Estimator 330/418, Train metric: 0.7047
# Estimator 331/418, Train metric: 0.7041
# Estimator 332/418, Train metric: 0.7020
# Estimator 333/418, Train metric: 0.7018
# Estimator 334/418, Train metric: 0.7009
# Estimator 335/418, Train metric: 0.6997
# Estimator 336/418, Train metric: 0.6990
# Estimator 337/418, Train metric: 0.6980
# Estimator 338/418, Train metric: 0.6963
# Estimator 339/418, Train metric: 0.6949
# Estimator 340/418, Train metric: 0.6941
# Estimator 341/418, Train metric: 0.6934
# Estimator 342/418, Train metric: 0.6907
# Estimator 343/418, Train metric: 0.6896
# Estimator 344/418, Train metric: 0.6888
# Estimator 345/418, Train metric: 0.6877
# Estimator 346/418, Train metric: 0.6858
# Estimator 347/418, Train metric: 0.6847
# Estimator 348/418, Train metric: 0.6836
# Estimator 349/418, Train metric: 0.6825
# Estimator 350/418, Train metric: 0.6821
# Estimator 351/418, Train metric: 0.6805
# Estimator 352/418, Train metric: 0.6793
# Estimator 353/418, Train metric: 0.6790
# Estimator 354/418, Train metric: 0.6783
# Estimator 355/418, Train metric: 0.6775
# Estimator 356/418, Train metric: 0.6763
# Estimator 357/418, Train metric: 0.6754
# Estimator 358/418, Train metric: 0.6741
# Estimator 359/418, Train metric: 0.6732
# Estimator 360/418, Train metric: 0.6726
# Estimator 361/418, Train metric: 0.6719
# Estimator 362/418, Train metric: 0.6712
# Estimator 363/418, Train metric: 0.6705
# Estimator 364/418, Train metric: 0.6696
# Estimator 365/418, Train metric: 0.6691
# Estimator 366/418, Train metric: 0.6682
# Estimator 367/418, Train metric: 0.6673
# Estimator 368/418, Train metric: 0.6660
# Estimator 369/418, Train metric: 0.6651
# Estimator 370/418, Train metric: 0.6640
# Estimator 371/418, Train metric: 0.6637
# Estimator 372/418, Train metric: 0.6631
# Estimator 373/418, Train metric: 0.6626
# Estimator 374/418, Train metric: 0.6617
# Estimator 375/418, Train metric: 0.6605
# Estimator 376/418, Train metric: 0.6597
# Estimator 377/418, Train metric: 0.6594
# Estimator 378/418, Train metric: 0.6590
# Estimator 379/418, Train metric: 0.6584
# Estimator 380/418, Train metric: 0.6577
# Estimator 381/418, Train metric: 0.6567
# Estimator 382/418, Train metric: 0.6556
# Estimator 383/418, Train metric: 0.6546
# Estimator 384/418, Train metric: 0.6545
# Estimator 385/418, Train metric: 0.6541
# Estimator 386/418, Train metric: 0.6539
# Estimator 387/418, Train metric: 0.6529
# Estimator 388/418, Train metric: 0.6523
# Estimator 389/418, Train metric: 0.6496
# Estimator 390/418, Train metric: 0.6495
# Estimator 391/418, Train metric: 0.6492
# Estimator 392/418, Train metric: 0.6484
# Estimator 393/418, Train metric: 0.6471
# Estimator 394/418, Train metric: 0.6462
# Estimator 395/418, Train metric: 0.6455
# Estimator 396/418, Train metric: 0.6453
# Estimator 397/418, Train metric: 0.6449
# Estimator 398/418, Train metric: 0.6442
# Estimator 399/418, Train metric: 0.6432
# Estimator 400/418, Train metric: 0.6425
# Estimator 401/418, Train metric: 0.6418
# Estimator 402/418, Train metric: 0.6414
# Estimator 403/418, Train metric: 0.6410
# Estimator 404/418, Train metric: 0.6401
# Estimator 405/418, Train metric: 0.6392
# Estimator 406/418, Train metric: 0.6389
# Estimator 407/418, Train metric: 0.6374
# Estimator 408/418, Train metric: 0.6372
# Estimator 409/418, Train metric: 0.6367
# Estimator 410/418, Train metric: 0.6361
# Estimator 411/418, Train metric: 0.6353
# Estimator 412/418, Train metric: 0.6337
# Estimator 413/418, Train metric: 0.6321
# Estimator 414/418, Train metric: 0.6315
# Estimator 415/418, Train metric: 0.6310
# Estimator 416/418, Train metric: 0.6300
# Estimator 417/418, Train metric: 0.6293
# Mean Squared Error: 7.03
#         Mean    StdDev  Actual
# 0  32.811474  2.399553    34.0
# 1  36.361176  2.039241    36.0
# 2  34.693741  2.549634    36.0
# 3  36.318729  1.670552    35.0
# 4  43.287109  2.454179    44.6

# %%
# Define the path for the Excel file
excel_path = "./drive/MyDrive/Concrete_ml/PGBM_Prob.xlsx"

# Plot the standard deviation of the predictions
plt.figure(figsize=(12, 6))
plt.plot(
    predictions_NGB_df['StdDev'],
    label='Standard Deviation',
    color='green',
    marker='o',
    linestyle='dashed'
)
plt.xlabel('Sample Index')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation of NGBoost Predictions')
plt.legend()
plt.grid(True)

# Save the standard deviation plot
stddev_plot_path = 'stddev_plot.png'
plt.savefig(stddev_plot_path)
plt.close()

# Plot the actual vs predicted mean with confidence intervals
plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(
    y_test,
    label='Actual',
    color='black',
    marker='o',
    linestyle='dashed',
    linewidth=1,
    markersize=4
)

# Plot predicted mean
plt.plot(
    predictions_NGB_df['Mean'],
    label='Predicted Mean',
    color='red',
    marker='x',
    linestyle='dashed',
    linewidth=1,
    markersize=4
)

# Calculate and plot confidence intervals
confidence_interval = 1.96 * predictions_NGB_df['StdDev']  # 95% confidence interval
plt.fill_between(
    np.arange(len(predictions_NGB_df)),
    predictions_NGB_df['Mean'] - confidence_interval,
    predictions_NGB_df['Mean'] + confidence_interval,
    color='blue',
    alpha=0.2,
    label='95% Confidence Interval'
)
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('NGBoost Predictions with Confidence Intervals')
plt.legend()
plt.grid(True)

# Save the prediction plot
prediction_plot_path = 'prediction_plot.png'
plt.savefig(prediction_plot_path)
plt.close()

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(excel_path, engine='xlsxwriter')

# Write the dataframe to a worksheet.
predictions_NGB_df.to_excel(writer, sheet_name='Predictions', index=False)

# Access the XlsxWriter workbook and worksheet objects from the writer object.
workbook = writer.book
worksheet = writer.sheets['Predictions']

# Insert the standard deviation plot into a new worksheet.
worksheet_stddev = workbook.add_worksheet('StdDev Plot')
worksheet_stddev.insert_image('A1', stddev_plot_path)

# Insert the prediction plot into a new worksheet.
worksheet_prediction = workbook.add_worksheet('Predictions Plot')
worksheet_prediction.insert_image('A1', prediction_plot_path)

# Close the Pandas Excel writer and output the Excel file.
writer.close()
print(f"Excel file saved at {excel_path}")

# Optionally, remove the image files now that they're embedded in the Excel file
os.remove(stddev_plot_path)
os.remove(prediction_plot_path)
# Out:
# Excel file saved at ./drive/MyDrive/Concrete_ml/PGBM_Prob.xlsx
